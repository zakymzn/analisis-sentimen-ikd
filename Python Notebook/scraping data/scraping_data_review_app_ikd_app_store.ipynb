# %%
import numpy as np
import pandas as pd
from app_store_scraper import AppStore
from datetime import date
# Out:
# c:\Users\zakymzn\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
ikd = AppStore(country='id', app_name='identitas-kependudukan-digital', app_id='6448944056')
# Out:
# 2024-05-28 09:48:50,196 [INFO] Base - Initialised: AppStore('id', 'identitas-kependudukan-digital', 6448944056)
# 2024-05-28 09:48:50,196 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/id/app/identitas-kependudukan-digital/id6448944056

# %%
ikd.review()
# Out:
# 2024-05-28 09:48:55,808 [INFO] Base - [id:6448944056] Fetched 80 reviews (80 fetched in total)
# 2024-05-28 09:49:02,017 [INFO] Base - [id:6448944056] Fetched 220 reviews (220 fetched in total)
# 2024-05-28 09:49:08,513 [INFO] Base - [id:6448944056] Fetched 380 reviews (380 fetched in total)
# 2024-05-28 09:49:09,266 [INFO] Base - [id:6448944056] Fetched 391 reviews (391 fetched in total)

# %%
result = ikd.reviews
result
# Out:
# [{'date': datetime.datetime(2023, 12, 14, 13, 31, 40),
#   'review': 'Maaf admin, sebagai masukan. \n\nMasalah: masih ada tahapan yang mana pemohon masih harus ke kantor Dukcapil utk melakukan verifikasi barcode. \n\nSolusi: sekiranya tahapan verifikasi barcode pada kantor dukcapil di gantikan dengan verifikasi online menggunakan vidio interaktif dengan operator dan/atau mengirimi barcode ke email dan/atau nomer tlfn dan/atau cara lainnya yang sifatnya online\n\nTujuan: agar mempermudah dan efektivitas  seluruh tahapan yang dilakukan oleh pemohon dalam pengajuan Identitas Kependudukan Digital tanpa melewati prinsip kehati-hatian dan rahasia data pribadi \n\nHarapan: semoga seluruh produk dukcapil mengenai data diri atau identitas bisa dalam satu app atau superapps dukcapil agar terujud nya goverment yang efektif dan efisien \n\nTerimakasi 🙏🏻',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'APN41',
#   'title': 'Masukan'},
#  {'date': datetime.datetime(2023, 8, 4, 8, 51, 45),
#   'review': 'Seriusan apanya yang online kalo tetep disuruh dateng ke dukcapil?, sia sia gw bayar pajak tiap tahun cuma buat ngempanin orang2 tolol yg kerja di dukcapil 🤣🤣🤣',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Ganti Nama, jadi entaraja',
#   'title': 'Aplikasi Tolol'},
#  {'date': datetime.datetime(2023, 8, 23, 3, 20, 45),
#   'review': 'Katanya digital tapi masih diharuskan datang ke dukcapil untuk scan QR, seharusnya pada saat registrasi itu QRnya otomatis di kirim ke email. Mau digital elit mau QR sulit 🙄',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Nakam2323',
#   'title': 'Sulit'},
#  {'date': datetime.datetime(2023, 8, 8, 13, 50, 50),
#   'review': 'Tolong yg bener lah , masa online tapi disuruh dateng ke kantor , lawak banget',
#   'rating': 1,
#   'isEdited': False,
#   'userName': '4swu',
#   'title': 'Kerja setengah setengah'},
#  {'date': datetime.datetime(2023, 9, 27, 1, 27, 2),
#   'review': 'Pro’s: good security protection, you cannot print screen the data when you open the apps.👍\n\nCon’s: with budget provided and expense capex on the IT infrastructure for data recording, public should have better facilities and services. That’s still long way to go for my great country.',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'fjemmyc',
#   'title': 'Good start for digitalization.'},
#  {'date': datetime.datetime(2023, 10, 10, 6, 47, 32),
#   'review': 'Admin, mohon bantuan. saya tidak bisa buka dokumen kependudukan saya. Sudah pindah device, sudah uninstal trus instal lagi, bersihkan cache, force stop, semuanya sudah. Tapi tetap ga bisa dibuka dokumennya. Tolong bantuannya. Terima kasih',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'usergege',
#   'title': 'Tidak bisa buka dokumen kependudukan'},
#  {'date': datetime.datetime(2023, 10, 5, 7, 55, 47),
#   'review': 'Apa cuma aku di sini yang kalau klik dokumen malah loading dan error terus ? padahal koneksi internet lancar aja',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Ikhsan Siahaan',
#   'title': 'ERROR'},
#  {'date': datetime.datetime(2023, 10, 4, 11, 9, 9),
#   'review': 'sepertinya sdg ada problem, KTP dan KK tidak bisa tampil',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'wirawan_abcd',
#   'title': 'tampil dokumen lama'},
#  {'date': datetime.datetime(2024, 2, 3, 2, 39, 56),
#   'review': 'Sebelom diwajibkan install ini sama dukcapil karena saya pindah domisili, gak ada yg spam aneh aneh. Bahkan orang mau nipu pun gatau nama saya. Tapi setelahnya, ada bot tau nama lengkap saya, orang spam malware ke whatsapp. Ini data rakyat jangan dijual dong! Atau kalo gak ngerasa ngejual, artinya security nya jelek, nyesel masukin nomer hp.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'luminouscent',
#   'title': 'Data bocor?'},
#  {'date': datetime.datetime(2024, 4, 24, 6, 4, 5),
#   'review': 'aplikasi taek di buka aja ga bisa',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'cokksh',
#   'title': 'coook'},
#  {'date': datetime.datetime(2024, 1, 15, 6, 5, 6),
#   'review': 'Digital tapi harus scan qr ke dukcapil... konoha gk bener... pajak di naik2in cuma buat para pejabat yg butuh duit😅😅',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'jonin konoha',
#   'title': 'Jangan ngelawak'},
#  {'date': datetime.datetime(2024, 1, 13, 12, 16, 6),
#   'review': 'Seharusnya kl mau online dibuat comprehensive, masa ke Dukcapil lg\nKode QRnya dikirim ke email saja',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'KSaragih',
#   'title': 'Kenapa hrs minta QR ke Dukcapil?'},
#  {'date': datetime.datetime(2024, 1, 6, 14, 42, 1),
#   'review': 'Digital ndasmu, apanya yg digital kalo harus tetap pergi ke dukcapil? Digital cuman jargon gimmick doang',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Hypercaffium',
#   'title': 'Tidak Efisien, Cuman gimick “digital”'},
#  {'date': datetime.datetime(2023, 9, 19, 16, 9, 31),
#   'review': 'Akhirnya Rilis juga di IOS, Aplikasinya sudah bagus cuma perlu bbrpa perubahan kedepan lagi dan tambahan menu yg lbh canggih, untuk yg blg harus scan barcode mmg begitu caranya, lagian cuma scan sekali saja apa susah nya sih datang ke kantor capil😅',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Khairul Adami',
#   'title': 'Bagus'},
#  {'date': datetime.datetime(2023, 6, 8, 0, 17, 16),
#   'review': 'dupcapil bisa dan prima',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'naila mchlle',
#   'title': 'dupcapil'},
#  {'date': datetime.datetime(2023, 8, 3, 6, 59, 11),
#   'review': 'Ternyata harus datang langsung ke Disdukcapil.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'penggunalawas22',
#   'title': 'Aplikasi tiada guna 👌🏻'},
#  {'date': datetime.datetime(2024, 5, 24, 5, 8, 29),
#   'review': 'Aplikasi apa ini cok gajelas, katanya online tapi diminta datang ke dukcapil juga.. keat!',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Rhwna',
#   'title': 'App jembut'},
#  {'date': datetime.datetime(2024, 5, 24, 2, 57, 4),
#   'review': 'Scan QR ke Dukcapil? Sama aja bhong wkwk,ribet',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'junioranwar',
#   'title': 'Abisin waktu,uinstal apps'},
#  {'date': datetime.datetime(2024, 5, 23, 0, 29, 49),
#   'review': 'Saya sdh ada KTP digital sjk thn lalu Itupun pas aja ngurus surat2 keluarga sekalian aktivasi d dukcapil.Saya paham pemilik KTP hrs verifikasi fisik langsung dt4 krn siapa tau ada yg menyalahgunakan ektp org lain yg scr fisik serupa tp tak sama (misal org kembar).Sekali aja dukcapil datang kt4 saya diumumkan sehari sblmnya utk bantu warga verifikasi KTP digital dt4 ini jemput bola yg bagus!Hanya saja sayangnya app ini blm jelas pemakaian real d dunia nyata spt apa krn urusan administrasi dnegara ini msh serba fotocopy melulu.Sampe perpanjang sim stnk paspor msh fotocopy ektp jd ini aplikasi digital masih blm benar2 digunakan real msh sebatas kolektif warga aja dulu.Kedua yg bikin sesal adalah app ini hanya berjalan di 1 perangkat saja sdgkan jaman Now warga udah umum punya minimal 2hp!Shrsnya ada sistem tambah di perangkat baru dan di acc di perangkat pertama bukan malah dibatasi hanya bisa diakses di 1 perangkat saja klo diakses di perangkat baru maka hak akses di perangkat pertama langsung kehapus itu logika IT yg ga sesuai karakteristik warga indonesia yg punya multi devices!',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'BanhMiAhoi',
#   'title': 'Ya Sudahlah'},
#  {'date': datetime.datetime(2024, 5, 21, 7, 38, 11),
#   'review': 'Pendaftaran akun saja harus pakai QR dari petugas Dukcapil. Artinya harus bertemu dgn petugas lagi, sedangkan aplikasi dibuat agar semua urusan selesai secara online. Apa gunanya aplikasi kalau begitu? Informasi dalam aplikasi juga tidak jelas, membuat bingung dalam pengisiannya.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Jogsekala',
#   'title': 'Informasi Aplikasi Tidak Jelas'},
#  {'date': datetime.datetime(2024, 5, 15, 2, 50, 58),
#   'review': 'Kartu BPJS saya pernah mengalami nomor ganda. Sudah diperbaiki dan dihapus nomor yang salah, baik di kantor BPJS di Pancoran, maupun di Puskesmas di mana kami biasa berobat. Tapi kenapa di aplikasi ini masih tercantum nomor BPJS yang salah yang harusnya sudah ga ada??????? 🤬🤯',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'relentless mom',
#   'title': 'Nomor BPJS Salah'},
#  {'date': datetime.datetime(2024, 5, 21, 3, 40, 14),
#   'review': 'Hei pemerintah tolong lah.. anda bikin aplikasi kok masih nyusahin masyarakat? Ini tuh kek mana ya konsep aplikasinya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Lymolymo',
#   'title': 'Aplikasi sampah'},
#  {'date': datetime.datetime(2024, 5, 20, 6, 58, 11),
#   'review': 'Pas mau registrasi ktp , pas mau masuk ke Photo tiba” aplikasi terkeluar sendiri wkwkwk',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Wirayudamarpaung',
#   'title': 'Hm'},
#  {'date': datetime.datetime(2024, 5, 16, 1, 13, 43),
#   'review': 'memuat untuk membuka aplikasi sangat lamma',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'riooooooiiiisosi',
#   'title': 'loading terlalu lama'},
#  {'date': datetime.datetime(2024, 5, 15, 13, 19, 32),
#   'review': 'Buat apa download aplikasi kalau ujungnya mesti ke dukcapil juga ? ONLINE harusnya ga perlu ke kantor duckcapil lagi',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ronaldwi',
#   'title': 'Aplikasi online buat apa? Harus ke dukcapil juga'},
#  {'date': datetime.datetime(2024, 5, 15, 7, 40, 31),
#   'review': 'Gajelas wkwkwk ujung2nya ttp disuruh dateng ke kelurahan, kapan mau maju ini negara',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Kepinnn',
#   'title': 'ONLINE TAPI TETAP SURUH DATENG'},
#  {'date': datetime.datetime(2024, 5, 15, 3, 46, 49),
#   'review': 'Kk lewat email lewat sebulan tidak bisa dibuka lagi lalu suruh buka lewat apk idk ternyata sama aja ga bisa dibuka,, ini servernya yg overload atau emang apknya yg belum siap pakai\nPlease deh ini pelayanan utk masyarakat tapi kinerjanya seperti ini',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'dk212013',
#   'title': 'Tidak bisa dibuka'},
#  {'date': datetime.datetime(2024, 5, 13, 3, 40, 10),
#   'review': 'Saya minta cetak KK, sudah sebulan tidak ada perkembangan, datang ke Kelurahan, dianjurkan manual saja krn katanya memang di aplikasi tidak ada yg merespon. 😢',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'TeguhBdy',
#   'title': 'Tidak ada yg merespon layanan.'},
#  {'date': datetime.datetime(2024, 5, 14, 11, 23, 19),
#   'review': 'Bayar pajak terus tapi buat bayar orang kerja ga bener. Aplikasi online tapi tetep scan offline. Agak aneh emang',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Kamalshahab',
#   'title': 'Disuruh online setengah”'},
#  {'date': datetime.datetime(2024, 4, 26, 2, 42, 31),
#   'review': 'Pas buka aplikasi nya malah menghubungkan mulu padahal jaringan nya bagus',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'Ahahha fast',
#   'title': 'Oks'},
#  {'date': datetime.datetime(2024, 5, 11, 8, 13, 57),
#   'review': 'Sudah bagus digital sangat dimudahkan cukup dari gengaman tangan, tetapi kenapa harus registrasi mengunjungi Dukcapil setempat, kalau tinggalnya dekat dengan kota Lha kalau tinggalnya jauh dari kota mau ngurus harus menempuh perjalanan yang jauh terus gimana. Koq tak terpikirkan sepertinya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Danang Priyono',
#   'title': 'Ribet'},
#  {'date': datetime.datetime(2024, 5, 4, 5, 17, 38),
#   'review': 'Aplikasi tolol, app buatan indo malah menyusahkan bukan mempermudah🤡🤡🤡🤡🤡🤡',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'jeiangqcjncnwiiwhsOoalpq',
#   'title': 'Tolol🤡🤡🤡🤡🤡🤡'},
#  {'date': datetime.datetime(2024, 5, 1, 1, 40, 21),
#   'review': 'Saya pengajuan pembuatan akte sudah 2 minggu ga ada penjelasan sampai sekarang,entah di kerjain entah gimana,tolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya gini,aplikasi sering kali erorr ,dan pengajuan diem aja ga ada perubahan proses nya.\nSaya mau tanya\nKenapa sih urusan kependudukan ini Selalu RIBET,datang langsung ribet,ini udah pake aplikasi bukan nya mudah malah ribet juga',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Jojon88',
#   'title': 'Aplikasi tidak Bermutu'},
#  {'date': datetime.datetime(2024, 4, 29, 5, 5, 50),
#   'review': 'Aplikasi buruk, nyampe capil urus ktp rusak, ktp jadi gabole di ambil kalo belum log in ikd dan scan barcode. Gimana mau log in sedangkan aplikasi muter muter terus gak bisa log in. Sekalinya bisa log in pasti selalu nyalahin sinyal padahal sinyal full kuota BANYAKKKK LOL',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Gibran bagus',
#   'title': '1'},
#  {'date': datetime.datetime(2024, 4, 27, 6, 32, 20),
#   'review': 'Admin, mohon penjelesannya dan info nya. untuk aplikasi ini menu di menu dokumen ada pilihan KK dan KTP .pada saat sya ingin mmbagikan KK jika di bagikan muncul barcode untuk dipindai, fungsi nya ini apa ya??? karena saya pindai pun tidak bisa (situs tidak terdaftar) tanpa dibagikan pun KK nya hanya “lihat” di screenshot juga ngga bisa padahal lagi butuh. ini bagaimana ya mohon penjelasannya.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Arws smbg',
#   'title': 'perihal dokumen KK'},
#  {'date': datetime.datetime(2024, 4, 26, 20, 18, 7),
#   'review': 'Aplikasi tolol ga guna!!',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ada ajja',
#   'title': 'APK GAJELAS!'},
#  {'date': datetime.datetime(2024, 4, 24, 12, 53, 33),
#   'review': 'Sya udh berulang kai scan tidak bisa membaca…invalid',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'Hery latif',
#   'title': 'Tidak bisa scan'},
#  {'date': datetime.datetime(2024, 4, 26, 2, 29, 5),
#   'review': 'jangan berharap tinggi sama aplikasi berlogo garuda',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'cloudizerjogja',
#   'title': 'i n d o n e s i a'},
#  {'date': datetime.datetime(2024, 4, 25, 2, 52, 42),
#   'review': 'Aplikasinya ga bisa dipake. Force closed terus pada saat ambil foto. Pas buka lagi, dari awal lagi input NIK, dll.\nGa bisa dipakai. Tolong diperbaiki.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'MRDamanhuri',
#   'title': 'Force closed'},
#  {'date': datetime.datetime(2024, 4, 24, 7, 19, 31),
#   'review': 'Mau register harus ke dukcapil untuk dapat qr. Buat apa si… \nHarusnya bisa lebih di simplekan. Biar semua itu online. Klo harus datang ke dukcapil ma sama aja boong…',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'errorrerrorr',
#   'title': 'Register aja ribet'},
#  {'date': datetime.datetime(2024, 4, 4, 3, 43, 15),
#   'review': 'Sudah lama-lama antri untuk aktivasi IKD, pas mau discan barcode, kamera tidak bisa membaca barcodenya. Disuruh ganti hape. Mohon diperbaiki lagi.',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'Maminaniz',
#   'title': 'Aktivasi IKD'},
#  {'date': datetime.datetime(2024, 4, 24, 4, 15, 53),
#   'review': 'Bintang 1 dulu, fitur pelayanan ga berfungsi.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'santo ignacio',
#   'title': 'Fitur pelayanan ga berfungsi'},
#  {'date': datetime.datetime(2024, 4, 23, 1, 31, 21),
#   'review': 'apapun urusan anda, contoh misalkan buat pasor, mesti menunjukan fisik eKTP dan fotokopi eKTP lawak banget, eKTP masih di fotokopi hari gini??? terus melampirkan KK asli dan fotokopi KK, gila lu ndro, data-data kan sudah lengkap didalam di eKTP kenapa gak dipakai? juga menunjukan dokumen asli dan melampirkan fotokopi akte / ijazah / buku nikah, buset!! jadi ini digitalisasinya dimana ini?? 2024 masih terbelakang, gayanya canggih memanfaatkan teknologi, lawakan nasional',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'iDramous',
#   'title': 'lawakan nasional best world record'},
#  {'date': datetime.datetime(2024, 4, 22, 19, 28, 43),
#   'review': 'Apk ga guna maksudnya gimna masak login aja ga bisa gimna mau liat ktp klok login aja ga bisa tolongla admin di perbaiki lgi aplikasinya klok udah gini masyarakat yang repot bolak balik ke kantor ngabis2in biaya aja',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'undor undor',
#   'title': 'Belulok'},
#  {'date': datetime.datetime(2024, 4, 22, 5, 47, 26),
#   'review': 'gini nih aplikasi lokal….udah suruh bikin IKD, giliran dah di instal eeeeeeehhhhhh malah ga bisa di buka, saya sudah 4 hari ini install apk ini, tp belum bisa mengaksess…. please di perbaiki',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'plenyoen',
#   'title': 'tidak bisa di buka'},
#  {'date': datetime.datetime(2024, 4, 19, 23, 34, 56),
#   'review': 'Ktp saya dihilangkan orang lain, pada saat pengurusan kantor kecamatan katanya harus ada ktp digital , Sudah 1 minggu mau verifikasi wajah, ga pernah bisa, selalu muncul "ulangi ambil foto"',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'D4l3 l40h',
#   'title': 'Susah Verifikasi wajah'},
#  {'date': datetime.datetime(2024, 4, 19, 10, 37, 40),
#   'review': 'Mohon perbaikannya karena applikasinya loading trus tidak bisa di buka applikasinya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'sultanfareed',
#   'title': 'Tidak bisa di buka'},
#  {'date': datetime.datetime(2024, 4, 19, 1, 27, 54),
#   'review': 'Malah sirih datang ke dulcapil dong 😎',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ggdhdi',
#   'title': 'Malah sirih datang ke dulcapil dong 😎'},
#  {'date': datetime.datetime(2024, 4, 16, 6, 13, 58),
#   'review': 'Klo emg serius bikin aplikasi tu dengerin feedback user, matengin dulu sebelum rilis ke publik. Masih banyak bug, baru download koneksi internet lancar kok ya begitu masuk apk memuatnya ga selesai2. Sia2 gue bayar pajak cm buat bayar sdm yg model begini.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Zhafam',
#   'title': 'Aplikasi lawak'},
#  {'date': datetime.datetime(2024, 4, 6, 5, 13, 39),
#   'review': 'Aplikasi SAMPAH !!!',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Koruptor hukum mati',
#   'title': 'Sampah'},
#  {'date': datetime.datetime(2024, 4, 1, 0, 23, 22),
#   'review': 'Pas bukak aplikasi tidak bisa masuk. Berkali kali dicoba ttep gak bisa masuk ke menu. Hanya memuat dan loading dalam waktu lama',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'Davin lejar',
#   'title': 'Ga bisa masuk aplikasi'},
#  {'date': datetime.datetime(2024, 4, 3, 10, 53, 4),
#   'review': 'Katanya online , loh ko tetap harus ke dukcapil🤣🤣, sama juga bohong dong',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Kyugatsu',
#   'title': 'Ribet'},
#  {'date': datetime.datetime(2024, 4, 3, 6, 15, 37),
#   'review': 'Ni apk gimana sih, bener2 gabisa full online apa? Percuma aja bikin apk tapi harus dateng dulu ke kantor, kalo emang ga serius bikin apk mending gausah dah',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ex_heroez',
#   'title': 'Aplikasi tidak optimal'},
#  {'date': datetime.datetime(2024, 4, 2, 4, 13, 44),
#   'review': 'gak jelas balik ke beranda terus setelah isi data',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ndhhevdvz',
#   'title': 'tidak bagus'},
#  {'date': datetime.datetime(2024, 4, 1, 3, 0, 9),
#   'review': 'Aplikasinya cuman bisa di buka kalau pake wifi sedangkan ikd lebih di butuhin di luar dan otomatis lebih butuh di buka pake kuota tapi aplikasinya ga bisa di buka pake kuota… indosat btw kuotanya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'yudis135',
#   'title': 'Ga bisa buka kalo pake kuota'},
#  {'date': datetime.datetime(2024, 3, 28, 13, 24, 28),
#   'review': 'Kenapa aplikasi tidak dapat dibuka lagi padahal sudah saya coba berkali kali histori sudah saya hapus catche sudah saya bersihkan tapi tetep saja tidak bisa login',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'panggipan',
#   'title': 'Gagal masuk'},
#  {'date': datetime.datetime(2024, 3, 30, 11, 10, 13),
#   'review': 'Aplikasi isinya minta pin terus',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Lutfie86',
#   'title': 'Nyusahin'},
#  {'date': datetime.datetime(2024, 3, 29, 8, 4, 56),
#   'review': 'Untuk dokumen seperti Akta Kelahiran dan KK, saya tanyakan pada dukcapil untuk minta PDFnya katanya tidak bisa. Saya bisa lihat di IKD tapi tidak ada opsi Cetak atau Download. Kalau memang Go Digital sebaiknya bisa download sendiri tidak perlu ke Dukcapil lagi.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'francisleoni',
#   'title': 'Opsi untuk mencetak Akta, KK sendiri'},
#  {'date': datetime.datetime(2024, 3, 28, 1, 16, 19),
#   'review': 'Payah , apk untuk mempermudah tidak datang kesana kemari, ini malah ke dukcapil lagi, mending sekalian kasih datang suruh orang dukcapil urusin, keliatan banget jualannya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Dartono..',
#   'title': 'JUALAN APK DOANG'},
#  {'date': datetime.datetime(2024, 3, 26, 11, 16, 40),
#   'review': 'digitalisasi yg bagamimana ketika daftar harus ke dukcapil dan kesannya cuma buang anggaran seperti ini?\nsedangkan aplikasinya kalah dengan judi online😂',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'anggoro1830',
#   'title': 'kenapa digital harus ke dukcapil?'},
#  {'date': datetime.datetime(2024, 3, 19, 6, 29, 52),
#   'review': 'Padahal jaringan full tp mau buka selalu masalh jaringan, bagaimana ini?',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Padahal jaringan full',
#   'userName': 'Athayaleny'},
#  {'date': datetime.datetime(2024, 3, 24, 10, 35, 41),
#   'review': 'Judulnya online, tpi masih disuruh datang ke dukcapil ? Online darimananya ???',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Online abal”',
#   'userName': 'Sr0406'},
#  {'date': datetime.datetime(2024, 3, 24, 2, 33, 52),
#   'review': 'hadehh, masih aja ke kantor dukcapil😅😅😅',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'ngakngokngakngok',
#   'userName': 'morang kiki'},
#  {'date': datetime.datetime(2024, 3, 23, 19, 36, 1),
#   'review': 'Kenapa sih tidak bisa daftar online? Kenapa mesti ke kantor capil dulu cuman buat daftar? Trus apa gunanya ini aplikasi dibuat kalau gak bisa dipake secara online',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Tidak bisa daftar',
#   'userName': '(5678ksgdjfbfkshsis'},
#  {'date': datetime.datetime(2024, 3, 23, 12, 54, 23),
#   'review': 'Saya kira bisa verifikasi online langsung. Udah ada email dan no handphne. Masih aja harus dateng ke dukcapil. Auto Uninstall🔥',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Verifikasi ke Petugas Dukcapil',
#   'userName': 'tisnaeee'},
#  {'date': datetime.datetime(2024, 3, 19, 6, 43, 50),
#   'review': 'Sejatinya pemerintah kependudukan itu tolol semua, bodoh dan tidak mampu bekerja.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Tololl',
#   'userName': 'luis alvarisi'},
#  {'date': datetime.datetime(2024, 3, 19, 4, 5, 53),
#   'review': 'aplikasinya tidak bisa dibuka',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Masalah',
#   'userName': 'Wahyu TW'},
#  {'date': datetime.datetime(2024, 3, 19, 4, 13, 55),
#   'review': 'Aplikasi gak bisa dibuka, selalu gagal koneksi',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Gabisa dibuka aplikasinya',
#   'userName': 'Harits26'},
#  {'date': datetime.datetime(2024, 3, 19, 2, 4, 55),
#   'review': 'tidak bisa di buka.!',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Tdk bisa masuk.',
#   'userName': 'Wa Supriatna'},
#  {'date': datetime.datetime(2024, 3, 19, 3, 30, 49),
#   'review': 'Mohon untuk direview kembali aplikasinya. Saya sangat menghargai perubahan tapi mohon untuk dievaluasi secara berkala untuk setiap perubahan sistem. Sistem bilang “terjadi kesalahan jaringan”login padahal saya punya kuota dan pakai wifi. Mohon evaluasinya.',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Baru bisa dibuka pas malam, sedangkan untuk scan barcode harus pagi',
#   'userName': 'Bobby Hendrik'},
#  {'date': datetime.datetime(2024, 3, 19, 3, 26, 44),
#   'review': 'Mohon jaga kualitasnya, saya tidak bisa buka aplikasi, keterangan selalu kesalahan jaringan. Padahal saya sedang menggunakan wifi yg stabil namun tetap tidak bisa dibuka. Mohon perbaikan dan perhatiannya. Terimakasih',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Tidak bisa di buka aplikasinya',
#   'userName': 'an.diprabowo'},
#  {'date': datetime.datetime(2024, 3, 19, 2, 54, 59),
#   'review': 'Kenapa hp ios tidak dapat di gunakan ya? Memuat selalu coba lagi tidak dapat masuk ke app',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Untuk IOS aplikasi tidak dapat d gunakan',
#   'userName': 'IntanDiah199520'},
#  {'date': datetime.datetime(2024, 3, 19, 2, 47, 9),
#   'review': 'Aplikasi dibuat untuk mempermudah proses, yang terjadi sebaliknya. Membuat proses menjadi lebih sulit dan kompleks.\nAplikasi memberikan pesan “Terjadi kesalahan koneksi”, padahal koneksi ke internet (celluler dan wifi berjalan lancar).\nSaat di Kelurahan, tidak terdapat opsi proses lainnya selain via aplikasi, yang bermasalah.\nSangat tidak baik proses dan kualitas aplikasinya.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi Tidak Bisa Digunakan',
#   'userName': 'cndmax'},
#  {'date': datetime.datetime(2024, 3, 19, 2, 36, 50),
#   'review': 'Admin kenapa di ios tidak bisa ? Keluar notif jaringan padahal jariangannya aman',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Tidak memuaskan',
#   'userName': 'Lukman777886'},
#  {'date': datetime.datetime(2024, 3, 19, 1, 18, 43),
#   'review': 'Kok lelet banget ?',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Gak bisa kebuka',
#   'userName': 'Akhmad Agus Supiani'},
#  {'date': datetime.datetime(2024, 3, 19, 1, 18, 15),
#   'review': 'Tolong diperbaiki lagi untuk akses nya khusus pengguna iphone tidak bisa melakukan login!',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'APLIKASI EROR',
#   'userName': 'Mushlihul'},
#  {'date': datetime.datetime(2024, 3, 19, 0, 19),
#   'review': 'tidak bisa memuat. aplikasi macam apa ini',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'loading sangat lama',
#   'userName': 'dkydrmawan'},
#  {'date': datetime.datetime(2024, 3, 18, 23, 55, 15),
#   'review': 'Tidak bisa diakses setelah diunduh',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Koneksi bermasalah',
#   'userName': '94theodore'},
#  {'date': datetime.datetime(2024, 3, 18, 16, 6, 31),
#   'review': 'Baru download tetapi tidak bisa dibuka aplikasinya',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi tidak berfungsi dengan baik',
#   'userName': 'Hfhsjis'},
#  {'date': datetime.datetime(2024, 3, 18, 3, 27, 17),
#   'review': 'Saya sangat kecewa kepada pemerintah. Masa tiap kecamatan gaada blankon. Saya kehilangan ktp saya malah di suruh bkin digital ktp pake aplikasi ini. Bilang nya bisa di gunakan untuk keperluan apapun. Kenyataan nya tidak. Saya kesulitan membuat rekening baru karna di seluruh bank gabisa pake KTP digital! Pihak bank bilng blm ada peraturan memakai KTP digital! Jadi gimana ini? Ktp digital nya tidak bisa berguna …!',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Keluhan',
#   'userName': 'pengguna digital ktp'},
#  {'date': datetime.datetime(2024, 3, 7, 8, 15, 4),
#   'review': 'Baru download, ada ulasan di media online tanpa datang ke dukcapil, realitasnya harus minta scan barcode ke dukcapil... aplikasi utk mempermudah dan tanpa harus tatap muka. Sebagai bahan pengembangan, user requirement perlu mjd bahan utama perbaikan',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'Teguhsaja',
#   'title': 'Untuk pengembangan aplikasi'},
#  {'date': datetime.datetime(2024, 3, 14, 7, 57, 16),
#   'review': 'Mengapa aplikasi IKD ini hanya bisa di akses jika HP kita tersambung WIFI jika pake data selular aplikasi error tidak bisa di akses mohon solusinya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Rahmadawal',
#   'title': 'Aplikasi hanya bisa digunakan jika kita tersambung Ke WiFi'},
#  {'date': datetime.datetime(2024, 3, 10, 15, 33, 45),
#   'review': 'kocak katanta digital ngapain harus dateng ke dukcapil',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'jey444',
#   'title': 'kocak'},
#  {'date': datetime.datetime(2024, 3, 4, 13, 41, 22),
#   'review': 'ini saya udah daftar di capil beberapa bulan kemarin trz saya ganti hp dan di hape baru download IKD lagi tapi cuma ada menu daftar menu login gak ada???? kan aneh',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'masbay19',
#   'title': 'Tidak ada menu login'},
#  {'date': datetime.datetime(2024, 3, 7, 5, 16, 56),
#   'review': 'semua penanganan Tidak ada yang beres mulai Akte kematian,Kk,KTP di bikin Edan.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Sanusi211293',
#   'title': 'Tidak sesuai Harapan'},
#  {'date': datetime.datetime(2024, 3, 5, 0, 23, 3),
#   'review': 'Apl gjls lemot jaringan padahal lancar jaya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Tffghccd',
#   'title': 'Apl konyol'},
#  {'date': datetime.datetime(2024, 2, 24, 12, 43, 32),
#   'review': 'Mau daftar ktp digital malah ribet musti minta kode qr ke dukcapil masa 🤦\u200d♂️',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'YahGitu',
#   'title': 'Repot'},
#  {'date': datetime.datetime(2024, 3, 4, 11, 33, 13),
#   'review': 'Katanya canggih serba online🤣 sdh dtg dikantor capil, sdh daftar online pas discan eh katanya komputernya eror. Lawak bener. Paling bener mmg pake calo ga ada berapa jam sdh jadi.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Widyals',
#   'title': 'Lawak'},
#  {'date': datetime.datetime(2024, 3, 4, 6, 4, 23),
#   'review': 'Tolong dong , bikin app yg user friendly. \nAplikasi selalu loading. Lama sekali dibukanya. \nEra digitalisasi yg notabene memudahkan rakyat. Tapi malah bikin riweh krna aplikasi ga bisa dibuka',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'leli28373',
#   'title': 'Not useful'},
#  {'date': datetime.datetime(2024, 3, 4, 4, 37, 50),
#   'review': 'parah',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'asepbedog77',
#   'title': 'jaringan stabil koneksi gagal terus heran'},
#  {'date': datetime.datetime(2024, 3, 4, 4, 12, 2),
#   'review': 'UNTUK APA DIBIKIN ONLINE KALAU UJUNG”NYA SAAT DAFTAR HARUS KE KANTOR DUKCAPIL LAGI?',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Toni00123',
#   'title': 'GAK GUNA'},
#  {'date': datetime.datetime(2024, 3, 1, 12, 54, 44),
#   'review': 'aplikasinya ko gabisa dibuka yah setengah jam aku tungguin tapi ke ke buka',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'yufermanlase',
#   'title': 'aplikasinya ko gabisa dibuka yah setengah jam aku tungguin tapi ke ke buka'},
#  {'date': datetime.datetime(2024, 2, 28, 14, 33, 36),
#   'review': 'Lama banget loadingnya',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Gagegihna',
#   'title': 'Lemot'},
#  {'date': datetime.datetime(2024, 2, 28, 7, 0, 3),
#   'review': 'masa harus pakai jaringan kecamatan bru bisa buka. sdh pakai jaringan bagus tp cm bs dijaringan kecamatan . parah bgt. applikasinya pilih2 jaringan',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'bunga melati harum',
#   'title': 'Applikasinya susah dibuka'},
#  {'date': datetime.datetime(2024, 2, 28, 2, 54, 32),
#   'review': 'Sangat baik dan berguna',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'SunntTari98',
#   'title': 'Komentar'},
#  {'date': datetime.datetime(2024, 2, 27, 13, 28, 10),
#   'review': 'Namanya Digitalisasi itu verifikasinya tidak perlu ke dukcapil terdekat lagi.',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'Ronald Gollop',
#   'title': 'Digital Tapi Verifikasi Lokal'},
#  {'date': datetime.datetime(2024, 2, 26, 4, 38),
#   'review': 'Kalau memang mau transisi ke digital, dipersiapkan duku aplikasinya se-reliable mungkin. Ini buka aplikasi aja lama banget, klik menu lain lama lagi, ah bikin males.\nTolong dievaluasi dong tim engineer nya, jangan nyusahin hajat banyak orang. Makasih.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'sunatlaser',
#   'title': 'Aplikasi lemot parah'},
#  {'date': datetime.datetime(2024, 2, 25, 3, 1, 10),
#   'review': 'Nyesel downlod dulu, harusnya baca komen deh sblom download. Ini gprosedur haru datang ke dukcapil bukan online, tau kan kalo ngurus offline ke gimana lamanya . Buang buang waktu',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ginzzzz0101',
#   'title': 'Ribet'},
#  {'date': datetime.datetime(2024, 2, 24, 23, 12, 5),
#   'review': 'Sia sia duit pajak gua buat bayar aplikasi kayak begini',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Hambxx',
#   'title': 'Forgot akun harus dateng ke kecamatan'},
#  {'date': datetime.datetime(2024, 2, 23, 1, 21, 5),
#   'review': 'Pengajuan cetak ulang kartu keluarga tidak ada tindakan. Padahal sudah 1 bulan lebih',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Akpirandi Akhmar',
#   'title': 'Gunanya apa'},
#  {'date': datetime.datetime(2024, 2, 12, 2, 34, 47),
#   'review': 'kesalahan koneksi trussss kaga bisa masuk tolong perbaiki min…',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'mahrusaali',
#   'title': 'perbaiki!!!!'},
#  {'date': datetime.datetime(2024, 2, 22, 22, 57, 12),
#   'review': 'Emang verifikasi gak bisa via email, kok mesti scan QR code di disdukcapil?',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'cak onoy',
#   'title': 'Digitalisasi yang nanggung'},
#  {'date': datetime.datetime(2024, 2, 20, 10, 39, 53),
#   'review': 'Untuk iphone se, keypad yang muncul pada halaman ganti pin terpotong pada tombol nol sehingga tidak dapat memencet tombol nol (0). Akibatnya input pin yang benar tidak dapat dilakukan. Mohon perbaiki.',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'SilkATar',
#   'title': 'Keypad ganti pin bermasalah'},
#  {'date': datetime.datetime(2024, 2, 20, 1, 27, 43),
#   'review': 'App nya masih banyak kekurangan, salah satunya panduan untuk input Data tidak jelas khususnya Scan (Hanya stuck disitu aja).\nFungsi nya juga jelas mengarah kemana, yang ada kesan nya buang buang Uang negara ke pengembang yang tidak kompeten',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Badiksng',
#   'title': 'Invalid'},
#  {'date': datetime.datetime(2024, 2, 19, 13, 49, 31),
#   'review': 'Nama doang elektronik tp sistem jadul, gak guna',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'App gak guna bgt',
#   'title': 'App gak guna'},
#  {'date': datetime.datetime(2024, 2, 19, 1, 4, 11),
#   'review': 'KTP di gital tetep aja harus datang ke dekcapil',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Mr. veng',
#   'title': 'Pengen elit tapi birokrasi sulit'},
#  {'date': datetime.datetime(2024, 2, 18, 0, 46, 29),
#   'review': 'Terobosan baru Sebagai identitas digital, tapi Tidak pernah ada sosialisasi, sistemnya belum siap dan belum singkron antar lembaga. Seperti pengurusan terkait perbankan yg harus ktp asli, digital tidak mau. Ada fitur pengajuan online yg nyatanya tidak jalan kemarin pengajuan sudah sampai 6 bulan belum selesai dan akhirnya Pengurusan tetap datang ke layanan loket dan sama saja.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'SunriseOfJava',
#   'title': 'Fitur'},
#  {'date': datetime.datetime(2024, 2, 16, 22, 25, 36),
#   'review': 'Saya mau cetak KK susah amat, kenapa mesti harus ajukan permohonan cetak KK???? Tinggal cek di dokumen online kan bisa, tambahkan itu tombol unduh atau klik kanan save. Bodoh amat mempersulit pengguna.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'BastantaVicario',
#   'title': 'Parah amat yg buat aplikasi'},
#  {'date': datetime.datetime(2024, 2, 15, 6, 45, 57),
#   'review': 'Aplikasi penyusah, yg seharus nya di permudah malah di persulit, sudah ada scan wajah kenapa harus ada barcode dari dukcapil lagi ? Ribet amat',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'JohnVodd',
#   'title': 'Penyusah'},
#  {'date': datetime.datetime(2024, 2, 14, 2, 30, 44),
#   'review': 'Scan QR harus ke Dupcapil ? Ngapaaaain ? REPOT',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'bambaaang',
#   'title': 'GAK HERAN APLIKASI BUATAN PEMERINTAH !!!'},
#  {'date': datetime.datetime(2024, 2, 13, 11, 2, 30),
#   'review': 'Isi aplikasi nya keren, tapi daftar nya ke dukcapil juga mah sama aja, bisa dicari wayout lain biar full digital',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Mrizkiakbar',
#   'title': 'Cari cara lain biar gk dtg ke dukcapil'},
#  {'date': datetime.datetime(2024, 2, 13, 7, 13, 49),
#   'review': 'Digital harusnya mempermudah ya. Ini mau registrasi malah disuruh k dukcapil minta barcode. Buat apa coba',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'I Gusti Ngurah Yogi Swara',
#   'title': 'Keluhan'},
#  {'date': datetime.datetime(2024, 2, 12, 4, 55, 11),
#   'review': 'appnya gabisa kebuka padahal sinyal saya lancar',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'resqilah',
#   'title': 'app gabisa terbuka'},
#  {'date': datetime.datetime(2024, 2, 7, 0, 9, 19),
#   'review': 'Apa2 serba ribet. Aplikasi lelet parah,,,korup korup',
#   'rating': 2,
#   'isEdited': False,
#   'userName': ')?/)/$2',
#   'title': 'Blog goblok'},
#  {'date': datetime.datetime(2024, 2, 11, 11, 5, 1),
#   'review': 'Niat mau daftar, eh ada verifikasi dan validasi ke dukcapil. Batal daftar deh. Harusnya bisa metode lain seperti perbankan saat buka tabungan.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'dodyagung',
#   'title': 'Harus verifikasi offline'},
#  {'date': datetime.datetime(2024, 2, 10, 12, 13, 54),
#   'review': 'Kok gak scan e-ktp ny aja ya? Padahal kata ny dlu e-ktp pke teknologi jerman yg pke nfc ? Ini kok malah di suruh qr code minta ke petugas 🤣',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'engineersans',
#   'title': 'Scan qr'},
#  {'date': datetime.datetime(2024, 2, 10, 8, 27, 58),
#   'review': 'Aplikasi gak guna\nBuat apa online klo masih harus scan QR verifikasi ke kantor? Kocak!!!🤦🏻\u200d♀️',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'tuhhhjj',
#   'title': 'Suruh QR kode ke sana, lah kata nya online?'},
#  {'date': datetime.datetime(2024, 2, 10, 7, 48, 37),
#   'review': 'Lawak banget nih Aplikasi, katanya Online. Tapi tetap harus ke Dukcapil dulu cuma buat dapetin QR-CODE doang😅. Masih lbh baik E-SIM. QR-CODE di kirim ke email. Makin gk jelas nih negara. Petingginya lawak semua😅',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Rahmat Ana',
#   'title': 'Negeri Lawak'},
#  {'date': datetime.datetime(2024, 2, 9, 0, 34, 44),
#   'review': 'Aplikasi tdk dapat di akses',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Awal fadli',
#   'title': 'M'},
#  {'date': datetime.datetime(2024, 2, 7, 8, 16, 56),
#   'review': 'Ga bisa buka sama sekali memut terus',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'ali jaeni',
#   'title': 'Tolong'},
#  {'date': datetime.datetime(2024, 2, 3, 11, 16, 24),
#   'review': 'Untuk tipe iphone kecil (SE, 5S, 5 dst) UI untuk menekan pin tidak bisa dilakukan karna tidak muncul semua tombol nya, mohon perbaiaki developer nya',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Atur Ukuran UI PIN',
#   'userName': 'Agus39'},
#  {'date': datetime.datetime(2024, 2, 6, 3, 6, 38),
#   'review': 'Kenapa harus ke dukcapil buat dapat qr kode. Dan fungsi apa juga kalo kita daftarkan emailnya.\nSimpel tapi di bikin ribet',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Qc code ke dukcapil, BUAT APA???????',
#   'userName': 'Xsasixngd'},
#  {'date': datetime.datetime(2024, 1, 23, 1, 39, 50),
#   'review': 'Kenapa beberapa minggu ini aplikasi gk bisa dibuka…? Udh diupgrade dab uninstal dan download lagi tetap g bisa dibuka,,,apakah ada gangguan,apa gmn?',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'KTP',
#   'userName': 'pardisiregar'},
#  {'date': datetime.datetime(2024, 1, 31, 9, 49, 4),
#   'review': 'Sebagai masukan saja ya admin, sesuai kebanyakan yg sudah ditulis ulasan oleh teman2\nSeharusnya klo sdh digitalisasi utk mendapatkan barcodenya bisa di kirim lewat email jdi tdk perlu lgi dtg ke kantor dukcapil setempat\nMhn maaf ya sya kasih bintang 1',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Identitas Kependudukan Digital',
#   'userName': 'Ogeb1'},
#  {'date': datetime.datetime(2024, 1, 31, 3, 52, 52),
#   'review': 'Apanya yg mempermudah. Malah tambah sulit aplikasinya ampas tdk bsa kebuka',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi tidak bisa di buka parah',
#   'userName': 'kelukelulo'},
#  {'date': datetime.datetime(2024, 1, 31, 2, 21, 3),
#   'review': 'Jaringan lancar untk sosmed dan apk lainnya.. tp baru buka apk ini aja udh erorr mulu',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Erorrrrr',
#   'userName': 'RRPCTM'},
#  {'date': datetime.datetime(2024, 1, 29, 11, 30, 31),
#   'review': 'Proses implementasinya dengan pegawai pemerintahan juga kurang, masa sy sudah pindahkan ktp fisik ke digital, tetap saja saat mengurus sesuatu ke pemerintahan yang diminta fotokopi ktp/fisik nya, hadeh.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi seperti belum siap layak dipakai alias seadanya',
#   'userName': 'Juan Kahfi'},
#  {'date': datetime.datetime(2024, 1, 29, 8, 31, 40),
#   'review': 'Pin dah bener namun salah kata aplikasinya; Masa gak ada menu reset pin; padahal ada email dan no hp yg diminta saat daftar; developer nya kurang cerdas sih',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Apliksi bodoh',
#   'userName': 'iwalakabar'},
#  {'date': datetime.datetime(2024, 1, 28, 19, 22, 11),
#   'review': 'Ppppp',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Apk babi,ga bisa di buka',
#   'userName': 'asu...!$7'},
#  {'date': datetime.datetime(2024, 1, 27, 10, 20, 18),
#   'review': 'mohon maaf 🙏 apk ini tidak bisa di buka yah? \n keterangan di apk pas di buka selalu coba lagi ,',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'komplain',
#   'userName': 'ryu adika pratama'},
#  {'date': datetime.datetime(2024, 1, 25, 2, 35, 8),
#   'review': 'Kalo mau bikin yang online petugasnya SDM nya di kasih tau jangan kudet aplikasinya aja ianvalid terus kocak',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Kocak',
#   'userName': 'kocakgaming999'},
#  {'date': datetime.datetime(2024, 1, 25, 2, 0, 9),
#   'review': 'tolonggg ini kenapa tidak bisa dibuka aplikasinyaaaa gunanya ini aplikasi agar tidak mempersulit tapi ini malah kebalikannyaa',
#   'rating': 1,
#   'isEdited': False,
#   'title': '.',
#   'userName': 'pp23466'},
#  {'date': datetime.datetime(2024, 1, 24, 9, 28, 43),
#   'review': 'Setelah daptar trus foto, minta scan QR, kukira dikirim ke email, eh ternyata dugaanku terlalu berlebihan',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Buruk',
#   'userName': 'rodok ruwet'},
#  {'date': datetime.datetime(2024, 1, 24, 1, 58, 41),
#   'review': 'Aplikasi tidak bisa dibuka',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi tidak bisa dibuka',
#   'userName': 'yosep rizal'},
#  {'date': datetime.datetime(2024, 1, 19, 6, 39, 25),
#   'review': 'Kenapa di iPhone gk bisa foto saat foto keluar mulu gmnaa ini',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Tidak bisa di gunakan pengguna iPhone iOS',
#   'userName': 'Susi tara'},
#  {'date': datetime.datetime(2024, 1, 22, 2, 29, 10),
#   'review': 'jujur ini lebih ribet daripada yg dicetak, karena kita disuruh daftar saja di hp tapi gabisa dibuka apalagi untuk ios muter2 saja dan eror. dan ga semua orang punya hp. belum lagi kalo mau ngurus2 harus pakai ktp yg cetak, ribet sumpah. tolong dong perbaiki lagi sistemnya',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'erorrrr',
#   'userName': 'Hei Miko'},
#  {'date': datetime.datetime(2024, 1, 18, 0, 27, 43),
#   'review': 'Why? Whyyyy? Kenapa? Kenapa masih perlu ke dukcapil hanya untuk scan barcode?😭😭',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Menyedihkan',
#   'userName': 'reggithamartha'},
#  {'date': datetime.datetime(2024, 1, 17, 5, 29, 42),
#   'review': 'katanya online tapi malah disuru dateng ke dukcakil 🤣',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'udah enggak heran',
#   'userName': 'ulik jabri'},
#  {'date': datetime.datetime(2024, 1, 17, 5, 23, 49),
#   'review': 'Data keluarga di aplikasi yg muncul ga lengkap, masa istri gw kaga ada, kata petugasnya masih proses pindah, lah padahal ngurus pindahannya tahun 2019 ampe terbit KK fisiknya udh pindah wqwq',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Data keluarga ga lengkap',
#   'userName': 'Qudthul'},
#  {'date': datetime.datetime(2024, 1, 16, 6, 52, 31),
#   'review': 'Sudah ada IKD tapi di bandara, perbankan suruh ktp cetak, dikasi printout tetep gabisa, terus aplikasinya juga bodoh, giliran saat penting  lg dibandara, bank, servernya down capeeekk, buntuk di korupsi yaa kaya gini',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi jelek namanya program pemerintah pasti gaada yang bener',
#   'userName': 'Andra Mahardika'},
#  {'date': datetime.datetime(2024, 1, 9, 13, 14, 18),
#   'review': 'Kenapa untuk cek Biodata Lainnya hanya muncul “Dokumen tidak tersedia/hak akses terbatas”',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Dokumen tidak tersedia',
#   'userName': 'mipftah'},
#  {'date': datetime.datetime(2024, 1, 11, 9, 43, 12),
#   'review': 'Aplikasinya perlu diperbaiki lagi, susah untuk login…😮\u200d💨',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Perlu diperbaiki lagi',
#   'userName': 'Mude GZ'},
#  {'date': datetime.datetime(2024, 1, 5, 2, 51, 22),
#   'review': 'Belum semua daerah tahu IKD, apalagi Polisi dan Bank. Tolong prosesnya dipercepat.',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Keluhan',
#   'userName': 'Jean’s99'},
#  {'date': datetime.datetime(2024, 1, 8, 6, 3, 2),
#   'review': 'Sepertinya Dukcapil masih belum siap dengan sistem online. Pengurusan untuk pencetakan KTP masih harus memerlukan dokumen fisik berupa fotokopi KK. \nBukankah petugasnya bisa akses data kita dari aplikasi? Masa lebih canggih kecamatan daripada dukcapilnya. SDM rendah tidak sejalan dengan inovasi digitalisasi yang dilakukan.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Tidak berfungsi Optimal',
#   'userName': 'fzp_f'},
#  {'date': datetime.datetime(2024, 1, 8, 4, 21, 17),
#   'review': '€rror',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi €rror',
#   'userName': 'richrobert'},
#  {'date': datetime.datetime(2024, 1, 7, 10, 1, 22),
#   'review': "disyarat dan ketentuan kok ada tulisan \n'Negara Bagian'?\nini ori APK indonesia ???",
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Negara Bagian ?',
#   'userName': 'ch4o5myth'},
#  {'date': datetime.datetime(2024, 1, 7, 9, 49, 39),
#   'review': 'Katanya online, tpi ujung2nya qr nya harus minta ke kantor',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Harus ke kantor juga',
#   'userName': 'Lul.ung'},
#  {'date': datetime.datetime(2024, 1, 7, 7, 53, 45),
#   'review': 'Sudan isi banyak data, kerjaan aplikasi ya cm muter aaja . Tidak bisa menampilkan apa yang diperintahkan sesuai yang Ada di menu',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi yang buang want dan menyusahkan',
#   'userName': 'MehKittyz'},
#  {'date': datetime.datetime(2024, 1, 6, 10, 46, 4),
#   'review': 'Masih bingung dengan negara bagian yang dimaksud dalam tnc',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Negara bagian',
#   'userName': 'hprasetyou'},
#  {'date': datetime.datetime(2024, 1, 6, 6, 9, 15),
#   'review': 'App sampah, buka dokumen kependudukan muter” mulu',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Sampah',
#   'userName': '96619gjan'},
#  {'date': datetime.datetime(2024, 1, 6, 3, 5, 7),
#   'review': 'Kenapa masih perlu ofline sih? Kan KK ada QR nya? Apa gak bisa pakai QR kk saja?',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'App belum jadi?',
#   'userName': 'Guz lo'},
#  {'date': datetime.datetime(2024, 1, 6, 2, 33, 50),
#   'review': 'Untuk apa dibuat aplikasi digital kalau masih antri datang ke dukcapil..',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Apanya yg digital',
#   'userName': 'Mr Sns'},
#  {'date': datetime.datetime(2024, 1, 6, 2, 19, 48),
#   'review': 'Instlal ikd koq hrs ke dukcapil nya ya buat dpt qr code soalnya ada kt lanjutkan tp ga bisa dklik',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Ikd',
#   'userName': 'siok tju'},
#  {'date': datetime.datetime(2024, 1, 5, 16, 46, 41),
#   'review': 'INOVASI YG PERLU BANYAK RENOVASI. Mau daftar harus didampingi petugas dukcapil, tidak praktis',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Aplikasi Mobile phone yg tidak Mobile',
#   'userName': 'yohanesph'},
#  {'date': datetime.datetime(2024, 1, 5, 2, 56, 48),
#   'review': 'Apa pengertian ‘online’ gw yg salah ya??',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Si Paling Online',
#   'userName': 'Si Paling Online'},
#  {'date': datetime.datetime(2024, 1, 4, 9, 24, 13),
#   'review': 'Mau log in malah memuat terus dan error padahal koneksi lancar huuuu',
#   'rating': 1,
#   'isEdited': False,
#   'title': '👎',
#   'userName': 'Andira17'},
#  {'date': datetime.datetime(2024, 1, 4, 5, 23, 26),
# ...
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'zizi yoyo',
#   'title': 'Semoga semakin handal'},
#  {'date': datetime.datetime(2023, 6, 22, 6, 7),
#   'review': 'Mohon diperbaiki aplikasinya untuk verifikasi cukup dengan foto ktp dan wajah memegang ktp. Tidak perlu verifikasi ke kantor kelurahan ribet, buang2 waktu saja.\nPerbankan dan Aplikasi e commerce saja sdh lebih baik dan cepat. \nAyo dukcapil ditunggu terobosan terbaiknya.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'anoname1',
#   'title': 'Tidak Praktis'},
#  {'date': datetime.datetime(2023, 6, 20, 1, 29, 5),
#   'review': 'Untuk apa ini?',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'incho69',
#   'title': 'Masyarakat'},
#  {'date': datetime.datetime(2023, 6, 20, 8, 47, 28),
#   'review': 'Sok-sok an mau digital/online tapi tetap aja musti datang ke kantor utk scan QR. Berapa nilai anggaran nya utk bikin aplikasi ini? Balikin aja anggaran nya, biar offline lagi‼️',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Reallydoes',
#   'title': 'Buang-buang anggaran‼️'},
#  {'date': datetime.datetime(2023, 6, 19, 2, 6, 47),
#   'review': 'Untuk pelayanan KTP Digital oleh pihak Kemendagri sangat memuaskan Pelayanan, cepat dan ramah',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'ibu ijja',
#   'title': 'IKD'},
#  {'date': datetime.datetime(2023, 6, 19, 22, 54, 54),
#   'review': 'Semoga bermanfaat dan makin memudahkan dalam pelayanan',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'aznifa',
#   'title': 'Mantap'},
#  {'date': datetime.datetime(2023, 6, 19, 6, 24, 28),
#   'review': 'Masak mau bikin identitas digital harus disuruh pake Gmail. Padahal emailnya cuma punya outlook. Kalo pake outlook nggak bisa dan ga dapat verifikasi email buat aktifasi.🫣',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Auyokri',
#   'title': 'Developer Appnya Cupu'},
#  {'date': datetime.datetime(2023, 6, 16, 9, 55, 26),
#   'review': 'Sangat setuju sekali adanya aplikasi ini👍👍',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'biiiiiiillllllllaaaaaaaaah',
#   'title': 'Bilaaaa'},
#  {'date': datetime.datetime(2023, 6, 15, 2, 50, 43),
#   'review': 'hatur nuhun..',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'ratu anggista',
#   'title': 'hatur nuhun..'},
#  {'date': datetime.datetime(2023, 6, 14, 3, 12, 56),
#   'review': 'Mantap',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'meylani intan',
#   'title': 'Sip'},
#  {'date': datetime.datetime(2023, 6, 15, 2, 44, 20),
#   'review': 'Kalo hrs reg. ke kantor mh nya atuh kr naon dibikin e-id yg seharusnya mmbantu ini malah sebaliknya 😩',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Comsenta',
#   'title': 'Hadeuh'},
#  {'date': datetime.datetime(2023, 6, 13, 4, 19, 45),
#   'review': 'Apakah data kami akan bocor seperti halnya pedulilindungi?',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'PJ091',
#   'title': 'Apakah'},
#  {'date': datetime.datetime(2023, 6, 10, 5, 34, 27),
#   'review': 'Cara menggunakannya bagaimana?',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Cara',
#   'userName': 'izalludin'},
#  {'date': datetime.datetime(2023, 6, 13, 4, 4, 12),
#   'review': 'Mantulll',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'IKD',
#   'userName': 'TetiFf'},
#  {'date': datetime.datetime(2023, 6, 13, 2, 37, 34),
#   'review': 'Sudah aplikasi online tapi mesti datang ke dukcapil lagi dan mesti register di depan petugas dukcapil, lah terus e-ktp yg dibuat dulu sama KK fungsinya apa? Kok yo buat sesuatu nanggung nanggung',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Nyusahin',
#   'userName': 'Defricuy'},
#  {'date': datetime.datetime(2023, 6, 13, 1, 51, 46),
#   'review': 'Pegawainya Isi Bintang  5 Sendiri😂',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Ul',
#   'userName': 'iinnnuuu'},
#  {'date': datetime.datetime(2023, 6, 7, 15, 40, 12),
#   'review': 'mantap apk nya, mempermudah buat yg ketinggalan ktp-el nya & bisa lngsung di lihat di hp aja 😍',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'IKD',
#   'userName': 'nia.nyuttttt'},
#  {'date': datetime.datetime(2023, 6, 9, 3, 39, 28),
#   'review': 'aplikasi saya daftar selasa tanggal 6 juni lalu, hari ini saya mau cek buka aplikasi disuruh daftar lagi, tidak ada pilihan login atau masukan pin, bagaimana ya',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'tidak bisa login disuruh daftar lagi',
#   'userName': 'Delamvro'},
#  {'date': datetime.datetime(2023, 6, 6, 7, 28, 3),
#   'review': 'Kl kadang lupa nik anak atau akta cukup buka aplikasi ini, kl dokumen biasa lupa menaruhnya dmn MANTAAAPPPPP',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'Mantap',
#   'userName': 'Afrizal S'},
#  {'date': datetime.datetime(2023, 6, 7, 8, 40, 40),
#   'review': 'Aplikasi yang sangat membantu dan memudahkan sekali',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Aplikasi keren',
#   'userName': 'Nur Meida TR'},
#  {'date': datetime.datetime(2023, 6, 7, 8, 36, 44),
#   'review': 'Waahh menarik sekali 🤩',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'KTP DIGITAL',
#   'userName': 'Pi-sank'},
#  {'date': datetime.datetime(2023, 6, 7, 8, 18, 8),
#   'review': 'Mantap',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Mantap',
#   'userName': 'fuadstn'},
#  {'date': datetime.datetime(2023, 6, 7, 6, 29, 56),
#   'review': 'Aplikasi bagus sangat membantu jika lupa ktp',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Best App',
#   'userName': 'didi mahendra'},
#  {'date': datetime.datetime(2023, 6, 7, 0, 5, 30),
#   'review': 'Keren',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Jhony',
#   'userName': 'Agung Krisna'},
#  {'date': datetime.datetime(2023, 6, 6, 11, 48, 54),
#   'review': 'Mudah di pahami dan sangat bermanfaat, semoga kedepannya bisa sinkron di terima oleh seluruh pelayanan publik, seperti Kepolisian, Bank, Moda Transportasi, dsb, terimakasih Dukcapil Kendal',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Pelayanan IKD',
#   'userName': 'dayat berdoa kebaikan'},
#  {'date': datetime.datetime(2023, 6, 6, 9, 30, 10),
#   'review': 'Berguna sekali aplikasi ini untuk proses yang membutuhkan ktp. Jadi gak perlu bawa fisik e-ktp',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Keren',
#   'userName': 'lasahido'},
#  {'date': datetime.datetime(2023, 6, 6, 9, 0, 21),
#   'review': 'Bangga banget bisa mengikuti perkembangan 🤝',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'KTP Digital',
#   'userName': 'Izzar ghiffari'},
#  {'date': datetime.datetime(2023, 6, 6, 8, 11, 47),
#   'review': 'IKD mantap, DUKCAPIL GO GDIGITAL♥️🔥🔥🔥',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'MANTAP♥️♥️♥️💙💙💙🔥🔥🔥',
#   'userName': 'I CALL FR'},
#  {'date': datetime.datetime(2023, 6, 6, 7, 54, 26),
#   'review': 'Semoga aplikasi lebih berkembang sehingga dapat mempermudah pelayanan publik',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Mantap',
#   'userName': 'Shaqeel77'},
#  {'date': datetime.datetime(2023, 6, 6, 7, 20, 46),
#   'review': 'Dengan adanya KTP digital tidak khawatir lagi  kemana-kemana, tidak khawatir KTP rusak untuk seumur hidup, tidak perlu bawa akte lahir dan Kartu keluarga karena sudah ada dalam genggaman',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'KTP Seumur Hidup',
#   'userName': 'DanelloBee'},
#  {'date': datetime.datetime(2023, 6, 6, 7, 7, 41),
#   'review': 'Keren',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'KTP Digital',
#   'userName': 'siripin'},
#  {'date': datetime.datetime(2023, 6, 6, 7, 0, 41),
#   'review': 'Bisa mempermudah segala urusan yang berkaitan dengan KTP',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Dukcapil bisa',
#   'userName': 'Jaksa agung'},
#  {'date': datetime.datetime(2023, 6, 3, 6, 30, 56),
#   'review': 'Saya mencoba screenshoot layar untuk print ktp, tetapi tidak berhasil. Apakah ada cara lain untuk print ktp-el? Terima kasih.',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'HnM1991',
#   'title': 'Masalah print ktp-el'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 48, 30),
#   'review': 'yeayy udh bisa di diphone 🫶🏻',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'ledamajid',
#   'title': 'IKD'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 44, 4),
#   'review': 'Sesuai dengan era 5.0 yang segalanya berbasis teknologi. Memudahkan kami sbg masyarakat dalam melakukan berbagai kebutuhan yg berhubungan dengan KTP, KK, NPWP dll.',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'aruniii',
#   'title': 'Sangat membantu sekali'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 41, 7),
#   'review': 'Dukcapil bisa dan prima',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'masibnu',
#   'title': 'Dukcapil bisa dan prima'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 34, 36),
#   'review': 'Agar ditingkatkan lagi performanya dan isinya supaya benar-benar menjadi identitas digital sebagai hub pelayanan publik di Indonesia',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Rio Syakban',
#   'title': 'KTP Digital yang sebenarnya'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 33, 42),
#   'review': 'sangat membantu dan lebih praktis dalam penggunaan dan pemilikian dokumen kependudukan',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'zvshsjks',
#   'title': 'ikd'},
#  {'date': datetime.datetime(2023, 6, 6, 6, 32, 21),
#   'review': 'Semoga kedepannya aplikasi ini bs dimanfaatkan dg maksimal dan bs terintegerasi dg sistem pemerintahan lainnya spt bpjs dan npwp',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Gusti Nana',
#   'title': 'Bagus'},
#  {'date': datetime.datetime(2023, 5, 29, 4, 16, 26),
#   'review': 'Akhire rilis tenan gawe ip',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'Dhy_',
#   'title': '?'},
#  {'date': datetime.datetime(2023, 6, 1, 9, 13, 41),
#   'review': 'KTP digital (online) tapi proses verifikasi masih harus ada petugas disdukcapil (offline).\nSedikit ribet jika kita pekerja reguler harus izin dahulu.',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'aqshaqshaqsha',
#   'title': 'Verifikasi'},
#  {'date': datetime.datetime(2023, 5, 29, 11, 26, 49),
#   'review': 'Di percepat perkenalan Ktp digital ini ke instansi / lembaga lain agar bisa menerima Ktp digital bukan cuma Ktp fisik.\nKarena jika sudah di terima ke semua pasti ini sangat bermanfaat di banding Ktp fisik.\nDi jaman sekarang orang lebih milih bawa gadget dibanding bawa dompet. \nSemua sudah era digital.\nYuk bisa yukkkk….',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'rendss',
#   'title': 'KTP Digital di terima ke semua lembaga'},
#  {'date': datetime.datetime(2023, 5, 27, 12, 26, 52),
#   'review': 'mantep bgt deh',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'karinapn',
#   'title': 'mantep'},
#  {'date': datetime.datetime(2023, 5, 26, 10, 39, 55),
#   'review': 'Sangat membantu...👍🏻👍🏻',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Iqbal__',
#   'title': 'Keren...'},
#  {'date': datetime.datetime(2023, 5, 27, 9, 46, 28),
#   'review': 'Tolong saya diapaksa download aplikasi 🥹🥹🥹',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'bgxu opong',
#   'title': 'SAYA DIPAKSA'},
#  {'date': datetime.datetime(2023, 5, 26, 8, 26, 49),
#   'review': 'Semoga bisa digunakan di segala layanan',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'fattahul94',
#   'title': 'Identitas Digital'},
#  {'date': datetime.datetime(2023, 5, 25, 13, 16, 39),
#   'review': 'Tidak Perlu Khawatir jika KTP Ketinggalan',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'komen komen',
#   'title': 'Sangat Membantu'},
#  {'date': datetime.datetime(2023, 5, 25, 5, 57, 23),
#   'review': 'Pemanfaatan data kependudukan',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'luthenrique21',
#   'title': 'Bermanfaat'},
#  {'date': datetime.datetime(2023, 5, 25, 7, 39, 8),
#   'review': 'Harus minta kode QR dari dukcapil',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'abdul wawa',
#   'title': 'Susah'},
#  {'date': datetime.datetime(2023, 5, 25, 4, 42, 51),
#   'review': 'Sangat berguna..👍👍👍👍',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'pras_utomo',
#   'title': 'IKD mantap..👍👍'},
#  {'date': datetime.datetime(2023, 5, 25, 4, 36, 41),
#   'review': 'Memudahkan melihat ktp digital dan KK',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'firdiman',
#   'title': 'Memudahkan'},
#  {'date': datetime.datetime(2023, 5, 25, 4, 17, 57),
#   'review': 'Semoga bisa tersedia dokumen lainnya seperti bpjs dll',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Herysetiawan',
#   'title': 'Tingkatkan'},
#  {'date': datetime.datetime(2023, 5, 25, 4, 6, 58),
#   'review': 'Memudahkan sekali',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Humaray',
#   'title': '👍'},
#  {'date': datetime.datetime(2023, 5, 25, 3, 31, 23),
#   'review': 'Mantap',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'tans199666383882',
#   'title': '👍🏻👍🏻👍🏻👍🏻👍🏻'},
#  {'date': datetime.datetime(2023, 8, 25, 7, 42, 27),
#   'review': 'Yang pada protes bilang digital tapi harus datang ke kantor, mungkin pada tolol kali ya? Itu namanya pemerintah bener2 menjaga keamanan saat verifikasi. Verifikasi ktp digital bener2 terpasang di HP bersangkutan. Kalo verifikasi semudah verifikasi pinjol, ntar kalo data lu disalah gunain orang karena mudah bgt verif nya mau??? \nYang pada bilang cetak mandiri tapi masih datang ke kelurahan dll, kayanya emang elu sih yang tolol gatau caranya. Cetak mandiri nyetak sendiri padahal, selama itu bukan blangko KTP atau KIA. Makanya kalo tolol itu belajar. Kebiasaan +62 udah tolol, nyolot pula.',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Buat yang udah baca bintang 1, wajib baca ini.',
#   'userName': 'berlianafd'},
#  {'date': datetime.datetime(2023, 6, 7, 1, 34, 18),
#   'review': 'Sangat membantu pelayanan , bintang 100000000000',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Mantap',
#   'userName': 'dyatrii'},
#  {'date': datetime.datetime(2023, 7, 22, 7, 44, 58),
#   'review': 'Ini apalimasi online apa offline kenapa tetep harus datang ke dukcapil. Anehh yg kasih bintang 5 pegawainya sendiri. Coba duku mas aplikasinya baru kasih bintang. Biar aplikasinya berkembang, kalau kyk gini mah cuma abisin anggaran rakyat aja. Semoga kedepannya aplikasi pemerintah digarap dengan lebih baik dan bisa bersaing dengan aplikasi swasta',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'hjskskss',
#   'title': 'Aplikasi belum siap'},
#  {'date': datetime.datetime(2024, 5, 21, 2, 33, 26),
#   'review': 'NIK GUA 15 DIGIT GIMANA?\nGAK BISA PAKAI APK INI?',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'aldo2525',
#   'title': 'Apaansih'},
#  {'date': datetime.datetime(2024, 3, 26, 14, 13, 35),
#   'review': 'Dulu urus akte lahir anak sekaligus untuk KIA juga, hasilnya hanya akte lahir yg terbit ,, KIA menyusul alasan dr tmpt kelurahan\n 1. Covid \n2. Blangko kosong\n3. Nunggu barengan sm yg mau urus KIA\n akhirnya saya malas urus manual lg.\nSeneng donk Dapat info bs urus online tapi apahhhhhhh nyuruh tetep datang ke kantor supaya dapat QR verifikasi data.. sama aja bohong donk !!!! Niat mempermudah Ato mempersulit ya???????????????????????',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Nelly AP',
#   'title': 'Alibi Onlie , QR harus ke kantor dukcapil yang bener aja !'},
#  {'date': datetime.datetime(2024, 3, 4, 5, 32, 25),
#   'review': 'MAU DAFTAR AJA HARUS SCAN BARCODE ME DUKCAPIL RIBEEETTTT KORUPSI AJA LU BUKANNYA NGEMBANGIN SISTEM YG BAGUS UDH DIBAYAR JUGA SAMA RAKYAT !!!',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'rdennir',
#   'title': 'MANA ADA ONLINE TAPI HARUS TETEP KE DUKCAPIL'},
#  {'date': datetime.datetime(2024, 2, 28, 23, 40, 25),
#   'review': 'BURUK SEKALI EVERYBODY',
#   'rating': 1,
#   'isEdited': False,
#   'title': '(   )',
#   'userName': 'jelebuuu'},
#  {'date': datetime.datetime(2024, 2, 5, 17, 37, 3),
#   'review': 'ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DUCAKPIL, APUS AJA INI APP KLO GD UPDATE TERBARU HRS NYA OTOMATIS KEKIRIM KE EMAIL KEK, KAN ENAK SIMPLE',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'm4lskutt',
#   'title': 'MEMPERSULIT'},
#  {'date': datetime.datetime(2023, 10, 8, 12, 7, 57),
#   'review': 'WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE DUKCAPIL, APUS AJA APPS NYA',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Tommmm96s',
#   'title': 'Aplikasi gajelas'}]

# %%
len(result)
# Out:
# 391

# %%
df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                    date                                             review  \
# 0   2023-12-14 13:31:40  Maaf admin, sebagai masukan. \n\nMasalah: masi...
# 1   2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 2   2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 3   2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# 4   2023-09-27 01:27:02  Pro’s: good security protection, you cannot pr...
# ..                  ...                                                ...
# 386 2024-03-26 14:13:35  Dulu urus akte lahir anak sekaligus untuk KIA ...
# 387 2024-03-04 05:32:25  MAU DAFTAR AJA HARUS SCAN BARCODE ME DUKCAPIL ...
# 388 2024-02-28 23:40:25                             BURUK SEKALI EVERYBODY
# 389 2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 390 2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
#
#      rating  isEdited                   userName  \
# 0         3     False                      APN41
# 1         1     False  Ganti Nama, jadi entaraja
# 2         1     False                  Nakam2323
# 3         1     False                       4swu
# 4         5     False                    fjemmyc
# ..      ...       ...                        ...
# 386       1     False                   Nelly AP
# 387       1     False                    rdennir
# 388       1     False                   jelebuuu
# 389       1     False                   m4lskutt
# 390       1     False                  Tommmm96s
#
#                                                  title
# 0                                              Masukan
# 1                                       Aplikasi Tolol
# 2                                                Sulit
# 3                              Kerja setengah setengah
# 4                       Good start for digitalization.
# ..                                                 ...
# 386  Alibi Onlie , QR harus ke kantor dukcapil yang...
# 387       MANA ADA ONLINE TAPI HARUS TETEP KE DUKCAPIL
# 388                                              (   )
# 389                                        MEMPERSULIT
# 390                                   Aplikasi gajelas
#
# [391 rows x 6 columns]

# %%
df.count()
# Out:
# date        391
# review      391
# rating      391
# isEdited    391
# userName    391
# title       391
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv(f'../../Dataset/review_ikd_app_store_{date.today().strftime("%d-%m-%Y")}.csv', index=False)
