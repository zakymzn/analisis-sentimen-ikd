# %% [markdown]
# # **Analisis Sentimen Kepuasan Pengguna Aplikasi Identitas Kependudukan Digital (IKD) di Play Store**

# %% [markdown]
# oleh Ma'mur Zaky Nurrokhman

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import string
import re
import joblib
import matplotlib.pyplot as plt
import nltk
nltk.download('all')
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import *
from imblearn.over_sampling import SMOTE
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\zakymzn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Dataset Ulasan Aplikasi IKD di Play Store

# %% [markdown]
# #### 23 Maret 2024

# %%
# import dataset ulasan aplikasi IKD di Play Store pada bulan Maret 2024

df_ikd_play_store_maret = pd.read_csv('../../../data/raw/review_ikd_play_store_23-03-2024.csv')
df_ikd_play_store_maret
# Out:
#                                   reviewId                 userName  \
# 0     81b52f47-491c-4582-b059-40be372f36f3            Habibun Nazar
# 1     a1781cbf-278f-49db-9a2d-61f43cab0b1b        AutoSport RedLine
# 2     fc068e18-efa1-4c28-a97b-c41481ba7252        Annisa Kurniawati
# 3     3944fe8c-73cb-4252-b2eb-d6dd356a6805                Wawan Ina
# 4     3440918f-bd37-45ca-89ed-6ecae9ae3fe8        Rahwadi Putraluwu
# ...                                    ...                      ...
# 5117  7fcdee1d-105c-4e7d-9009-ce433a9e80ae                Ismail Is
# 5118  bb1be052-c18c-4a82-baf2-ed0fb34e98aa           Inayah Safitri
# 5119  a8629511-0d10-41ae-ab49-604c2f49d818       Kholidwalid Silver
# 5120  369db5d1-2531-4090-bb80-d3918ad7c53e                 Fajri Hz
# 5121  fd000f0c-5d19-41db-9c48-aee848cbc505  Berlian cahya Ramadhani
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                 ...
# 5117  https://play-lh.googleusercontent.com/a-/ALV-U...
# 5118  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5119  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5120  https://play-lh.googleusercontent.com/a-/ALV-U...
# 5121  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0     Aplikasi menyusahkan. dimana2 fungsi software ...      1             42
# 1     Sy Sangat kecewa aplikasi yang buruk.. Selesai...      1             37
# 2     Harus dibuka pake WiFi, kalo pake paket data p...      1            834
# 3     Aplikasi nya sangat sangat tdk membantu, saat ...      1            688
# 4     Sudah login berkali-kali tetap saja yg muncul ...      1            562
# ...                                                 ...    ...            ...
# 5117  Terimakasih baoak durjen atas aplikasi ikdnya ...      5              0
# 5118                         semoga aplikasi lebih baik      5              0
# 5119                                  Semoga lebih baik      5              0
# 5120  SAYA PAKAI DATA KARTU TRI CUMA MUTER2 DOANG, P...      5              0
# 5121                                  Semoga bermanfaat      5              0
#
#      reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0                   1.2.2  2024-03-14 12:58:56           NaN        NaN
# 1                   1.2.2  2024-02-26 08:21:08           NaN        NaN
# 2                   1.2.2  2024-01-06 20:59:10           NaN        NaN
# 3                   1.2.2  2024-02-20 18:22:08           NaN        NaN
# 4                   1.2.2  2024-01-31 17:19:20           NaN        NaN
# ...                   ...                  ...           ...        ...
# 5117                1.2.2  2024-01-04 10:33:49           NaN        NaN
# 5118                1.2.2  2024-01-04 10:21:41           NaN        NaN
# 5119                1.2.2  2024-01-04 09:44:45           NaN        NaN
# 5120                1.2.2  2024-01-04 09:34:00           NaN        NaN
# 5121                1.2.2  2024-01-04 09:08:18           NaN        NaN
#
#      appVersion
# 0         1.2.2
# 1         1.2.2
# 2         1.2.2
# 3         1.2.2
# 4         1.2.2
# ...         ...
# 5117      1.2.2
# 5118      1.2.2
# 5119      1.2.2
# 5120      1.2.2
# 5121      1.2.2
#
# [5122 rows x 11 columns]

# %% [markdown]
# #### 28 Mei 2024

# %%
# import dataset ulasan aplikasi IKD di Play Store pada bulan Mei 2024

df_ikd_play_store_mei = pd.read_csv('../../../data/raw/review_ikd_play_store_28-05-2024.csv')
df_ikd_play_store_mei
# Out:
#                                   reviewId                           userName  \
# 0     4abb1bdf-18f9-4afe-848f-481ffe926e62                   Khairil Aryan TV
# 1     185cf71c-0e71-470d-9803-9a7edd6c08d8                            Tri Tri
# 2     686e43c1-3d35-46ba-974a-8c4b4946e6a0                    Septi triastuti
# 3     887e97aa-85c2-4275-9292-79c8b6e287b8                      siti nurjanah
# 4     cd056626-9b4f-4351-8458-fff5ff29651f  Yakobus Yosef Krishna Banyu Dhewa
# ...                                    ...                                ...
# 2982  b6fb7b90-7875-4f9a-aaff-89ef16403800                  Srirusmi Srirusmi
# 2983  5b0756f2-af55-4a6b-b8f6-943171e3343b                              Napis
# 2984  4b729f71-597b-4385-89ba-17eb672b445d                         Nasrul shi
# 2985  21fb18b8-ec91-468d-8295-fae9d8af2a6c                        Abie Wijoyo
# 2986  919dd216-45ac-4bcd-8c6b-e2bc276bfcfa                 Aninda Bunga Citra
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 2982  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2983  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2984  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2985  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2986  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0     Apasih gunanya E-KTP tapi gak bisa cetak KTP-n...      1            407
# 1     Sebenarnya ini untuk mempermudah apa gimana si...      1             76
# 2     Aplikasi nya "terjadi kesalahan koneksi" ,suda...      1            129
# 3     Yang seharusnya memudahkan, jadinya bikin tamb...      1              1
# 4     Sangat mengecewakan dimana tampilan sangat bur...      1             37
# ...                                                 ...    ...            ...
# 2982  mau daftar koh ribet banget g bisa-bisa.Email ...      2              0
# 2983  Gak bisa buka dokumen KTP sama kartu keluarga,...      2              0
# 2984  Bagus, tapi sayang harus keducapil untuk menda...      2              0
# 2985  Yg bikin aplikasi ini idenya siapa sih,.. kok ...      2              0
# 2986  Ini bagaimana ganti PIN nya?.hp saya habis res...      2              0
#
#      reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0                   1.2.2  2024-05-01 08:41:45           NaN        NaN
# 1                     NaN  2024-05-06 12:51:28           NaN        NaN
# 2                   1.2.2  2024-05-02 09:41:54           NaN        NaN
# 3                   1.2.2  2024-05-21 05:00:13           NaN        NaN
# 4                   1.2.2  2024-04-28 14:29:37           NaN        NaN
# ...                   ...                  ...           ...        ...
# 2982                1.2.2  2023-08-03 15:45:43           NaN        NaN
# 2983                  NaN  2023-10-02 13:38:49           NaN        NaN
# 2984                1.2.2  2023-06-20 09:40:42           NaN        NaN
# 2985                1.2.2  2023-09-01 08:22:52           NaN        NaN
# 2986                1.2.2  2023-09-21 16:14:18           NaN        NaN
#
#      appVersion
# 0         1.2.2
# 1           NaN
# 2         1.2.2
# 3         1.2.2
# 4         1.2.2
# ...         ...
# 2982      1.2.2
# 2983        NaN
# 2984      1.2.2
# 2985      1.2.2
# 2986      1.2.2
#
# [2987 rows x 11 columns]

# %% [markdown]
# #### 30 Juni 2024

# %%
# import dataset ulasan aplikasi IKD di Play Store pada bulan Juni 2024

df_ikd_play_store_juni = pd.read_csv('../../../data/raw/review_ikd_play_store_30-06-2024.csv')
df_ikd_play_store_juni
# Out:
#                                    reviewId                userName  \
# 0      73fdbe57-87b6-47a2-95b4-f83249788e9d             this is Joe
# 1      686e43c1-3d35-46ba-974a-8c4b4946e6a0         Septi triastuti
# 2      4abb1bdf-18f9-4afe-848f-481ffe926e62        Khairil Aryan TV
# 3      648e9d18-9c40-46cc-b31a-887044363097         Yanuar Darmawan
# 4      185cf71c-0e71-470d-9803-9a7edd6c08d8                 Tri Tri
# ...                                     ...                     ...
# 24149  5646d45e-6f73-40a0-83c0-d58c757cd5fc         kunkertz alundh
# 24150  4fa01aae-a027-40a5-9f28-b5656c7f0405  Gusrianto Malinsaleman
# 24151  650411a8-3817-4dbe-ab8e-58def53e5c8c           Tassya Salisa
# 24152  5b90e78c-daf4-4dd9-a136-0ceae6d2957d        Jeremy Sinambela
# 24153  b1af24f0-6047-43fa-a556-3983469cebd6                  Aa Gip
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 24149  https://play-lh.googleusercontent.com/a/ACg8oc...
# 24150  https://play-lh.googleusercontent.com/a/ACg8oc...
# 24151  https://play-lh.googleusercontent.com/a/ACg8oc...
# 24152  https://play-lh.googleusercontent.com/a-/ALV-U...
# 24153  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Upayanya bagus membuat apk ini tapi benar2 use...      1
# 1      Aplikasi nya "terjadi kesalahan koneksi" ,suda...      1
# 2      Apasih gunanya E-KTP tapi gak bisa cetak KTP-n...      1
# 3      Sangat,,,, sangat,,, sangat jelek & buruk,,, u...      1
# 4      Sebenarnya ini untuk mempermudah apa gimana si...      1
# ...                                                  ...    ...
# 24149                          Cara scan barcode nya gmn      5
# 24150     Identitas penduduk digitalisasi mantap........      5
# 24151               itu ada scan kode ? yg di scan apa ?      1
# 24152  Selamat malam mohon izin ndan. Perihal scan ba...      1
# 24153  Untuk Wilayah Cirebon Kota, apakah sudah bisa ...      5
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                230                1.2.2  2024-06-05 13:27:32
# 1                168                1.2.2  2024-05-02 09:41:54
# 2                530                1.2.2  2024-05-01 08:41:45
# 3                314                1.2.2  2024-04-26 09:59:45
# 4                171                  NaN  2024-05-06 12:51:28
# ...              ...                  ...                  ...
# 24149              2                1.0.0  2022-07-09 09:46:01
# 24150              1                1.0.0  2022-06-22 10:08:49
# 24151              0                1.0.0  2022-07-15 11:11:11
# 24152              0                1.0.0  2022-06-30 22:06:32
# 24153              0                1.0.0  2022-06-09 21:02:50
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 24149                                                NaN                  NaN
# 24150                                                NaN                  NaN
# 24151                                                NaN                  NaN
# 24152                                                NaN                  NaN
# 24153  Minggu depan release, saat ini sedang bertahap...  2022-06-09 22:23:15
#
#       appVersion
# 0          1.2.2
# 1          1.2.2
# 2          1.2.2
# 3          1.2.2
# 4            NaN
# ...          ...
# 24149      1.0.0
# 24150      1.0.0
# 24151      1.0.0
# 24152      1.0.0
# 24153      1.0.0
#
# [24154 rows x 11 columns]

# %% [markdown]
# ### Dataset Ulasan Aplikasi IKD di App Store

# %% [markdown]
# #### 24 April 2024

# %%
# import dataset ulasan aplikasi IKD di App Store pada bulan April 2024

df_ikd_app_store_april = pd.read_csv('../../../data/raw/review_ikd_app_store_24-04-2024.csv')
df_ikd_app_store_april
# Out:
#                     date                                             review  \
# 0    2023-10-10 06:47:32  Admin, mohon bantuan. saya tidak bisa buka dok...
# 1    2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 2    2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 3    2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# 4    2023-10-05 07:55:47  Apa cuma aku di sini yang kalau klik dokumen m...
# ..                   ...                                                ...
# 359  2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 360  2024-04-22 19:28:43  Apk ga guna maksudnya gimna masak login aja ga...
# 361  2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
# 362  2023-06-07 01:34:18   Sangat membantu pelayanan , bintang 100000000000
# 363  2024-04-23 01:31:21  apapun urusan anda, contoh misalkan buat pasor...
#
#      rating  isEdited                   userName  \
# 0         3     False                   usergege
# 1         1     False  Ganti Nama, jadi entaraja
# 2         1     False                  Nakam2323
# 3         1     False                       4swu
# 4         1     False             Ikhsan Siahaan
# ..      ...       ...                        ...
# 359       1     False                   m4lskutt
# 360       2     False                undor undor
# 361       1     False                  Tommmm96s
# 362       5     False                    dyatrii
# 363       1     False                   iDramous
#
#                                     title
# 0    Tidak bisa buka dokumen kependudukan
# 1                          Aplikasi Tolol
# 2                                   Sulit
# 3                 Kerja setengah setengah
# 4                                   ERROR
# ..                                    ...
# 359                           MEMPERSULIT
# 360                               Belulok
# 361                      Aplikasi gajelas
# 362                                Mantap
# 363    lawakan nasional best world record
#
# [364 rows x 6 columns]

# %% [markdown]
# #### 28 Mei 2024

# %%
# import dataset ulasan aplikasi IKD di App Store pada bulan Mei 2024

df_ikd_app_store_mei = pd.read_csv('../../../data/raw/review_ikd_app_store_28-05-2024.csv')
df_ikd_app_store_mei
# Out:
#                     date                                             review  \
# 0    2023-12-14 13:31:40  Maaf admin, sebagai masukan. \n\nMasalah: masi...
# 1    2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 2    2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 3    2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# 4    2023-09-27 01:27:02  Pro’s: good security protection, you cannot pr...
# ..                   ...                                                ...
# 386  2024-03-26 14:13:35  Dulu urus akte lahir anak sekaligus untuk KIA ...
# 387  2024-03-04 05:32:25  MAU DAFTAR AJA HARUS SCAN BARCODE ME DUKCAPIL ...
# 388  2024-02-28 23:40:25                             BURUK SEKALI EVERYBODY
# 389  2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 390  2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
#
#      rating  isEdited                   userName  \
# 0         3     False                      APN41
# 1         1     False  Ganti Nama, jadi entaraja
# 2         1     False                  Nakam2323
# 3         1     False                       4swu
# 4         5     False                    fjemmyc
# ..      ...       ...                        ...
# 386       1     False                   Nelly AP
# 387       1     False                    rdennir
# 388       1     False                   jelebuuu
# 389       1     False                   m4lskutt
# 390       1     False                  Tommmm96s
#
#                                                  title
# 0                                              Masukan
# 1                                       Aplikasi Tolol
# 2                                                Sulit
# 3                              Kerja setengah setengah
# 4                       Good start for digitalization.
# ..                                                 ...
# 386  Alibi Onlie , QR harus ke kantor dukcapil yang...
# 387       MANA ADA ONLINE TAPI HARUS TETEP KE DUKCAPIL
# 388                                              (   )
# 389                                        MEMPERSULIT
# 390                                   Aplikasi gajelas
#
# [391 rows x 6 columns]

# %% [markdown]
# #### 30 Juni 2024

# %%
# import dataset ulasan aplikasi IKD di App Store pada bulan Juni 2024

df_ikd_app_store_juni = pd.read_csv('../../../data/raw/review_ikd_app_store_30-06-2024.csv')
df_ikd_app_store_juni
# Out:
#                     date                                             review  \
# 0    2023-12-14 13:31:40  Maaf admin, sebagai masukan. \r\n\r\nMasalah: ...
# 1    2023-10-10 06:47:32  Admin, mohon bantuan. saya tidak bisa buka dok...
# 2    2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 3    2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 4    2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# ..                   ...                                                ...
# 436  2024-03-04 05:32:25  MAU DAFTAR AJA HARUS SCAN BARCODE ME DUKCAPIL ...
# 437  2024-02-28 23:40:25                             BURUK SEKALI EVERYBODY
# 438  2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 439  2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
# 440  2023-06-07 01:34:18   Sangat membantu pelayanan , bintang 100000000000
#
#      rating  isEdited                                         title  \
# 0         3     False                                       Masukan
# 1         3     False          Tidak bisa buka dokumen kependudukan
# 2         1     False                                Aplikasi Tolol
# 3         1     False                                         Sulit
# 4         1     False                       Kerja setengah setengah
# ..      ...       ...                                           ...
# 436       1     False  MANA ADA ONLINE TAPI HARUS TETEP KE DUKCAPIL
# 437       1     False                                         (   )
# 438       1     False                                   MEMPERSULIT
# 439       1     False                              Aplikasi gajelas
# 440       5     False                                        Mantap
#
#                       userName
# 0                        APN41
# 1                     usergege
# 2    Ganti Nama, jadi entaraja
# 3                    Nakam2323
# 4                         4swu
# ..                         ...
# 436                    rdennir
# 437                   jelebuuu
# 438                   m4lskutt
# 439                  Tommmm96s
# 440                    dyatrii
#
# [441 rows x 6 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Menggabungkan Dataset Berdasarkan Sumbernya Masing-Masing

# %% [markdown]
# #### Menggabungkan Dataset Ulasan Aplikasi IKD di Play Store

# %%
# menggabungkan semua dataset ulasan aplikasi IKD di Play Store

df_ikd_play_store = pd.concat([
    df_ikd_play_store_maret,
    df_ikd_play_store_mei,
    df_ikd_play_store_juni
]).reset_index()
df_ikd_play_store.drop(columns=['index'], inplace=True)
df_ikd_play_store
# Out:
#                                    reviewId                userName  \
# 0      81b52f47-491c-4582-b059-40be372f36f3           Habibun Nazar
# 1      a1781cbf-278f-49db-9a2d-61f43cab0b1b       AutoSport RedLine
# 2      fc068e18-efa1-4c28-a97b-c41481ba7252       Annisa Kurniawati
# 3      3944fe8c-73cb-4252-b2eb-d6dd356a6805               Wawan Ina
# 4      3440918f-bd37-45ca-89ed-6ecae9ae3fe8       Rahwadi Putraluwu
# ...                                     ...                     ...
# 32258  5646d45e-6f73-40a0-83c0-d58c757cd5fc         kunkertz alundh
# 32259  4fa01aae-a027-40a5-9f28-b5656c7f0405  Gusrianto Malinsaleman
# 32260  650411a8-3817-4dbe-ab8e-58def53e5c8c           Tassya Salisa
# 32261  5b90e78c-daf4-4dd9-a136-0ceae6d2957d        Jeremy Sinambela
# 32262  b1af24f0-6047-43fa-a556-3983469cebd6                  Aa Gip
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a/ACg8oc...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a/ACg8oc...
# 4      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                  ...
# 32258  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32259  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32260  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32261  https://play-lh.googleusercontent.com/a-/ALV-U...
# 32262  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Aplikasi menyusahkan. dimana2 fungsi software ...      1
# 1      Sy Sangat kecewa aplikasi yang buruk.. Selesai...      1
# 2      Harus dibuka pake WiFi, kalo pake paket data p...      1
# 3      Aplikasi nya sangat sangat tdk membantu, saat ...      1
# 4      Sudah login berkali-kali tetap saja yg muncul ...      1
# ...                                                  ...    ...
# 32258                          Cara scan barcode nya gmn      5
# 32259     Identitas penduduk digitalisasi mantap........      5
# 32260               itu ada scan kode ? yg di scan apa ?      1
# 32261  Selamat malam mohon izin ndan. Perihal scan ba...      1
# 32262  Untuk Wilayah Cirebon Kota, apakah sudah bisa ...      5
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                 42                1.2.2  2024-03-14 12:58:56
# 1                 37                1.2.2  2024-02-26 08:21:08
# 2                834                1.2.2  2024-01-06 20:59:10
# 3                688                1.2.2  2024-02-20 18:22:08
# 4                562                1.2.2  2024-01-31 17:19:20
# ...              ...                  ...                  ...
# 32258              2                1.0.0  2022-07-09 09:46:01
# 32259              1                1.0.0  2022-06-22 10:08:49
# 32260              0                1.0.0  2022-07-15 11:11:11
# 32261              0                1.0.0  2022-06-30 22:06:32
# 32262              0                1.0.0  2022-06-09 21:02:50
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 32258                                                NaN                  NaN
# 32259                                                NaN                  NaN
# 32260                                                NaN                  NaN
# 32261                                                NaN                  NaN
# 32262  Minggu depan release, saat ini sedang bertahap...  2022-06-09 22:23:15
#
#       appVersion
# 0          1.2.2
# 1          1.2.2
# 2          1.2.2
# 3          1.2.2
# 4          1.2.2
# ...          ...
# 32258      1.0.0
# 32259      1.0.0
# 32260      1.0.0
# 32261      1.0.0
# 32262      1.0.0
#
# [32263 rows x 11 columns]

# %%
# menghapus data duplikat pada dataset ulasan aplikasi IKD di Play Store

print(f"Jumlah data duplikat setelah proses penggabungan = {df_ikd_play_store.duplicated().sum()}")
df_ikd_play_store.drop_duplicates(inplace=True)
print(f"Jumlah data duplikat saat ini = {df_ikd_play_store.duplicated().sum()}")
# Out:
# Jumlah data duplikat setelah proses penggabungan = 2764
# Jumlah data duplikat saat ini = 0

# %%
print(f"Total data yang diambil dari Play Store yaitu {len(df_ikd_play_store)} data")
# Out:
# Total data yang diambil dari Play Store yaitu 29499 data

# %%
# menampilkan dataset ulasan aplikasi IKD di Play Store

df_ikd_play_store
# Out:
#                                    reviewId                userName  \
# 0      81b52f47-491c-4582-b059-40be372f36f3           Habibun Nazar
# 1      a1781cbf-278f-49db-9a2d-61f43cab0b1b       AutoSport RedLine
# 2      fc068e18-efa1-4c28-a97b-c41481ba7252       Annisa Kurniawati
# 3      3944fe8c-73cb-4252-b2eb-d6dd356a6805               Wawan Ina
# 4      3440918f-bd37-45ca-89ed-6ecae9ae3fe8       Rahwadi Putraluwu
# ...                                     ...                     ...
# 32258  5646d45e-6f73-40a0-83c0-d58c757cd5fc         kunkertz alundh
# 32259  4fa01aae-a027-40a5-9f28-b5656c7f0405  Gusrianto Malinsaleman
# 32260  650411a8-3817-4dbe-ab8e-58def53e5c8c           Tassya Salisa
# 32261  5b90e78c-daf4-4dd9-a136-0ceae6d2957d        Jeremy Sinambela
# 32262  b1af24f0-6047-43fa-a556-3983469cebd6                  Aa Gip
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a/ACg8oc...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a/ACg8oc...
# 4      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                  ...
# 32258  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32259  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32260  https://play-lh.googleusercontent.com/a/ACg8oc...
# 32261  https://play-lh.googleusercontent.com/a-/ALV-U...
# 32262  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Aplikasi menyusahkan. dimana2 fungsi software ...      1
# 1      Sy Sangat kecewa aplikasi yang buruk.. Selesai...      1
# 2      Harus dibuka pake WiFi, kalo pake paket data p...      1
# 3      Aplikasi nya sangat sangat tdk membantu, saat ...      1
# 4      Sudah login berkali-kali tetap saja yg muncul ...      1
# ...                                                  ...    ...
# 32258                          Cara scan barcode nya gmn      5
# 32259     Identitas penduduk digitalisasi mantap........      5
# 32260               itu ada scan kode ? yg di scan apa ?      1
# 32261  Selamat malam mohon izin ndan. Perihal scan ba...      1
# 32262  Untuk Wilayah Cirebon Kota, apakah sudah bisa ...      5
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                 42                1.2.2  2024-03-14 12:58:56
# 1                 37                1.2.2  2024-02-26 08:21:08
# 2                834                1.2.2  2024-01-06 20:59:10
# 3                688                1.2.2  2024-02-20 18:22:08
# 4                562                1.2.2  2024-01-31 17:19:20
# ...              ...                  ...                  ...
# 32258              2                1.0.0  2022-07-09 09:46:01
# 32259              1                1.0.0  2022-06-22 10:08:49
# 32260              0                1.0.0  2022-07-15 11:11:11
# 32261              0                1.0.0  2022-06-30 22:06:32
# 32262              0                1.0.0  2022-06-09 21:02:50
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 32258                                                NaN                  NaN
# 32259                                                NaN                  NaN
# 32260                                                NaN                  NaN
# 32261                                                NaN                  NaN
# 32262  Minggu depan release, saat ini sedang bertahap...  2022-06-09 22:23:15
#
#       appVersion
# 0          1.2.2
# 1          1.2.2
# 2          1.2.2
# 3          1.2.2
# 4          1.2.2
# ...          ...
# 32258      1.0.0
# 32259      1.0.0
# 32260      1.0.0
# 32261      1.0.0
# 32262      1.0.0
#
# [29499 rows x 11 columns]

# %% [markdown]
# #### Menggabungkan Dataset Ulasan Aplikasi IKD di App Store

# %%
# menggabungkan semua dataset ulasan aplikasi IKD di App Store

df_ikd_app_store = pd.concat([
    df_ikd_app_store_april,
    df_ikd_app_store_mei,
    df_ikd_app_store_juni
]).reset_index()
df_ikd_app_store.drop(columns=['index'], inplace=True)
df_ikd_app_store
# Out:
#                      date                                             review  \
# 0     2023-10-10 06:47:32  Admin, mohon bantuan. saya tidak bisa buka dok...
# 1     2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 2     2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 3     2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# 4     2023-10-05 07:55:47  Apa cuma aku di sini yang kalau klik dokumen m...
# ...                   ...                                                ...
# 1191  2024-03-04 05:32:25  MAU DAFTAR AJA HARUS SCAN BARCODE ME DUKCAPIL ...
# 1192  2024-02-28 23:40:25                             BURUK SEKALI EVERYBODY
# 1193  2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 1194  2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
# 1195  2023-06-07 01:34:18   Sangat membantu pelayanan , bintang 100000000000
#
#       rating  isEdited                   userName  \
# 0          3     False                   usergege
# 1          1     False  Ganti Nama, jadi entaraja
# 2          1     False                  Nakam2323
# 3          1     False                       4swu
# 4          1     False             Ikhsan Siahaan
# ...      ...       ...                        ...
# 1191       1     False                    rdennir
# 1192       1     False                   jelebuuu
# 1193       1     False                   m4lskutt
# 1194       1     False                  Tommmm96s
# 1195       5     False                    dyatrii
#
#                                              title
# 0             Tidak bisa buka dokumen kependudukan
# 1                                   Aplikasi Tolol
# 2                                            Sulit
# 3                          Kerja setengah setengah
# 4                                            ERROR
# ...                                            ...
# 1191  MANA ADA ONLINE TAPI HARUS TETEP KE DUKCAPIL
# 1192                                         (   )
# 1193                                   MEMPERSULIT
# 1194                              Aplikasi gajelas
# 1195                                        Mantap
#
# [1196 rows x 6 columns]

# %%
# menghapus data duplikat pada dataset ulasan aplikasi IKD di App Store

print(f"Jumlah data duplikat setelah proses penggabungan = {df_ikd_app_store.duplicated().sum()}")
df_ikd_app_store.drop_duplicates(inplace=True)
print(f"Jumlah data duplikat saat ini = {df_ikd_app_store.duplicated().sum()}")
# Out:
# Jumlah data duplikat setelah proses penggabungan = 709
# Jumlah data duplikat saat ini = 0

# %%
print(f"Total data yang diambil dari App Store yaitu {len(df_ikd_app_store)} data")
# Out:
# Total data yang diambil dari App Store yaitu 487 data

# %%
# menampilkan dataset ulasan aplikasi IKD di App Store

df_ikd_app_store
# Out:
#                      date                                             review  \
# 0     2023-10-10 06:47:32  Admin, mohon bantuan. saya tidak bisa buka dok...
# 1     2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 2     2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 3     2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# 4     2023-10-05 07:55:47  Apa cuma aku di sini yang kalau klik dokumen m...
# ...                   ...                                                ...
# 837   2024-05-01 01:40:21  Saya pengajuan pembuatan akte sudah 2 minggu g...
# 843   2024-04-25 02:52:42  Aplikasinya ga bisa dipake. Force closed terus...
# 845   2024-04-24 07:19:31  Mau register harus ke dukcapil untuk dapat qr....
# 1188  2024-06-06 20:47:45               KORUP BERMODALKAN APLIKASI CUIHHHHHH
# 1189  2024-05-21 02:33:26  NIK GUA 15 DIGIT GIMANA?\r\nGAK BISA PAKAI APK...
#
#       rating  isEdited                   userName  \
# 0          3     False                   usergege
# 1          1     False  Ganti Nama, jadi entaraja
# 2          1     False                  Nakam2323
# 3          1     False                       4swu
# 4          1     False             Ikhsan Siahaan
# ...      ...       ...                        ...
# 837        1     False                    Jojon88
# 843        1     False                MRDamanhuri
# 845        1     False               errorrerrorr
# 1188       1     False                   soerdjaa
# 1189       1     False                   aldo2525
#
#                                      title
# 0     Tidak bisa buka dokumen kependudukan
# 1                           Aplikasi Tolol
# 2                                    Sulit
# 3                  Kerja setengah setengah
# 4                                    ERROR
# ...                                    ...
# 837                 Aplikasi tidak Bermutu
# 843                           Force closed
# 845                     Register aja ribet
# 1188                                 KORUP
# 1189                              Apaansih
#
# [487 rows x 6 columns]

# %% [markdown]
# ### Feature Selection

# %%
# menghapus atribut-atribut yang tidak digunakan

df_ikd_play_store.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion'], inplace=True)
df_ikd_app_store.drop(columns=['date', 'isEdited', 'userName', 'title'], inplace=True)

# %%
# mengubah nama atribut

df_ikd_play_store.rename(columns={'content':'review','score':'sentiment'}, inplace=True)
df_ikd_app_store.rename(columns={'rating':'sentiment'}, inplace=True)

# %% [markdown]
# ### Menggabungkan Dataset Dari Kedua Sumber

# %%
# menggabungkan semua dataset menjadi satu dataframe

df = pd.concat([
    df_ikd_play_store,
    df_ikd_app_store
    ]).reset_index()
df.drop(columns=['index'], inplace=True)
df
# Out:
#                                                   review  sentiment
# 0      Aplikasi menyusahkan. dimana2 fungsi software ...          1
# 1      Sy Sangat kecewa aplikasi yang buruk.. Selesai...          1
# 2      Harus dibuka pake WiFi, kalo pake paket data p...          1
# 3      Aplikasi nya sangat sangat tdk membantu, saat ...          1
# 4      Sudah login berkali-kali tetap saja yg muncul ...          1
# ...                                                  ...        ...
# 29981  Saya pengajuan pembuatan akte sudah 2 minggu g...          1
# 29982  Aplikasinya ga bisa dipake. Force closed terus...          1
# 29983  Mau register harus ke dukcapil untuk dapat qr....          1
# 29984               KORUP BERMODALKAN APLIKASI CUIHHHHHH          1
# 29985  NIK GUA 15 DIGIT GIMANA?\r\nGAK BISA PAKAI APK...          1
#
# [29986 rows x 2 columns]

# %%
# melihat jumlah data duplikat

print(f"Jumlah data duplikat setelah proses penggabungan = {df.duplicated().sum()}")
df.drop_duplicates(inplace=True)
print(f"Jumlah data duplikat saat ini = {df.duplicated().sum()}")
# Out:
# Jumlah data duplikat setelah proses penggabungan = 10272
# Jumlah data duplikat saat ini = 0

# %%
# melihat jumlah data

print(f"Total data setelah kedua dataset digabungkan yaitu {len(df)} data")
# Out:
# Total data setelah kedua dataset digabungkan yaitu 19714 data

# %%
# reset index

df.reset_index(inplace=True)
df.drop(columns=['index'], inplace=True)
df
# Out:
#                                                   review  sentiment
# 0      Aplikasi menyusahkan. dimana2 fungsi software ...          1
# 1      Sy Sangat kecewa aplikasi yang buruk.. Selesai...          1
# 2      Harus dibuka pake WiFi, kalo pake paket data p...          1
# 3      Aplikasi nya sangat sangat tdk membantu, saat ...          1
# 4      Sudah login berkali-kali tetap saja yg muncul ...          1
# ...                                                  ...        ...
# 19709  Saya pengajuan pembuatan akte sudah 2 minggu g...          1
# 19710  Aplikasinya ga bisa dipake. Force closed terus...          1
# 19711  Mau register harus ke dukcapil untuk dapat qr....          1
# 19712               KORUP BERMODALKAN APLIKASI CUIHHHHHH          1
# 19713  NIK GUA 15 DIGIT GIMANA?\r\nGAK BISA PAKAI APK...          1
#
# [19714 rows x 2 columns]

# %%
# set opsi pandas agar bisa menampilkan full data

pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ### Pelabelan Data

# %%
# mengelompokan sentimen berdasarkan jumlah rating

print("Rating 4 dan 5 akan dikelompokan ke sentimen positif sedangkan rating 1,2, dan 3 akan dikelompokan ke sentimen negatif")

df.replace([1,2,3], "Negatif", inplace=True)
df.replace([4,5], "Positif", inplace=True)
df
# Out:
# Rating 4 dan 5 akan dikelompokan ke sentimen positif sedangkan rating 1,2, dan 3 akan dikelompokan ke sentimen negatif
#                                                                                                                                                                                                                                                                                                                                                                                                                                      review  \
# 0                                                                                                                                                                                                Aplikasi menyusahkan. dimana2 fungsi software itu untuk mempermudah, bukan sebaliknya. ini aku jauh2 dari rumah ke kantor dukcapil buat scan barcode brp kali bolak balik, tiap kesini error koneksi mulu padahal jaringan normal, bagus 👎
# 1                                                                                                                                                                                       Sy Sangat kecewa aplikasi yang buruk.. Selesai di daftarkan malah tidak bisa di buka..tiap kali di buka kesalahan koneksi... Tolong lah yang benar2 saja.. Kalau koneksi belum bisa diandalkan jgn dulu disarankan dan di wajibkan ke masyarakat...
# 2                                                                                                                                                                                                                Harus dibuka pake WiFi, kalo pake paket data pribadi gak bisa, alias memuat terus. Tolong dong, admin, diperbaiki ya aplikasinya. Masa harus nyari WiFi dulu baru bisa dibuka. Gak efektif, gak efisien, dan gak praktis..
# 3                                                                                                                                                                            Aplikasi nya sangat sangat tdk membantu, saat ingin membukanya malah tidak bisa.. Untuk apa Dukcapil mewajibkan menginstal aplikasi ini kalo hanya sekedar jadi pajangan di hape? Tolonglah di perbaiki lagi aplikasinya, saat ingin melihat data log in mudah
# 4                                                                                                                                                                                  Sudah login berkali-kali tetap saja yg muncul jaringan tidak stabil, padahal jaringan yg kita gunakan stabil,apk ap in saat di butuhkan enggak mau kebuka, harus menggunakan jaringan WiFi, tolong untuk di sesuaikan lagi,mana kita jauh2 dari dukcapil
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 19709  Saya pengajuan pembuatan akte sudah 2 minggu ga ada penjelasan sampai sekarang,entah di kerjain entah gimana,tolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya gini,aplikasi sering kali erorr ,dan pengajuan diem aja ga ada perubahan proses nya.\r\nSaya mau tanya\r\nKenapa sih urusan kependudukan ini Selalu RIBET,datang langsung ribet,ini udah pake aplikasi bukan nya mudah malah ribet juga
# 19710                                                                                                                                                                                                                                                                             Aplikasinya ga bisa dipake. Force closed terus pada saat ambil foto. Pas buka lagi, dari awal lagi input NIK, dll.\r\nGa bisa dipakai. Tolong diperbaiki.
# 19711                                                                                                                                                                                                                                                              Mau register harus ke dukcapil untuk dapat qr. Buat apa si… \r\nHarusnya bisa lebih di simplekan. Biar semua itu online. Klo harus datang ke dukcapil ma sama aja boong…
# 19712                                                                                                                                                                                                                                                                                                                                                                                                  KORUP BERMODALKAN APLIKASI CUIHHHHHH
# 19713                                                                                                                                                                                                                                                                                                                                                                                   NIK GUA 15 DIGIT GIMANA?\r\nGAK BISA PAKAI APK INI?
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %%
# menampilkan informasi dari dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19714 entries, 0 to 19713
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     19714 non-null  object
#  1   sentiment  19714 non-null  object
# dtypes: object(2)
# memory usage: 308.2+ KB

# %% [markdown]
# ### Case Folding

# %%
# mengubah semua huruf menjadi lower case

def lower(text):
    text = text.lower()
    return text

df['review'] = df['review'].apply(lower)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                      review  \
# 0                                                                                                                                                                                                aplikasi menyusahkan. dimana2 fungsi software itu untuk mempermudah, bukan sebaliknya. ini aku jauh2 dari rumah ke kantor dukcapil buat scan barcode brp kali bolak balik, tiap kesini error koneksi mulu padahal jaringan normal, bagus 👎
# 1                                                                                                                                                                                       sy sangat kecewa aplikasi yang buruk.. selesai di daftarkan malah tidak bisa di buka..tiap kali di buka kesalahan koneksi... tolong lah yang benar2 saja.. kalau koneksi belum bisa diandalkan jgn dulu disarankan dan di wajibkan ke masyarakat...
# 2                                                                                                                                                                                                                harus dibuka pake wifi, kalo pake paket data pribadi gak bisa, alias memuat terus. tolong dong, admin, diperbaiki ya aplikasinya. masa harus nyari wifi dulu baru bisa dibuka. gak efektif, gak efisien, dan gak praktis..
# 3                                                                                                                                                                            aplikasi nya sangat sangat tdk membantu, saat ingin membukanya malah tidak bisa.. untuk apa dukcapil mewajibkan menginstal aplikasi ini kalo hanya sekedar jadi pajangan di hape? tolonglah di perbaiki lagi aplikasinya, saat ingin melihat data log in mudah
# 4                                                                                                                                                                                  sudah login berkali-kali tetap saja yg muncul jaringan tidak stabil, padahal jaringan yg kita gunakan stabil,apk ap in saat di butuhkan enggak mau kebuka, harus menggunakan jaringan wifi, tolong untuk di sesuaikan lagi,mana kita jauh2 dari dukcapil
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 19709  saya pengajuan pembuatan akte sudah 2 minggu ga ada penjelasan sampai sekarang,entah di kerjain entah gimana,tolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya gini,aplikasi sering kali erorr ,dan pengajuan diem aja ga ada perubahan proses nya.\r\nsaya mau tanya\r\nkenapa sih urusan kependudukan ini selalu ribet,datang langsung ribet,ini udah pake aplikasi bukan nya mudah malah ribet juga
# 19710                                                                                                                                                                                                                                                                             aplikasinya ga bisa dipake. force closed terus pada saat ambil foto. pas buka lagi, dari awal lagi input nik, dll.\r\nga bisa dipakai. tolong diperbaiki.
# 19711                                                                                                                                                                                                                                                              mau register harus ke dukcapil untuk dapat qr. buat apa si… \r\nharusnya bisa lebih di simplekan. biar semua itu online. klo harus datang ke dukcapil ma sama aja boong…
# 19712                                                                                                                                                                                                                                                                                                                                                                                                  korup bermodalkan aplikasi cuihhhhhh
# 19713                                                                                                                                                                                                                                                                                                                                                                                   nik gua 15 digit gimana?\r\ngak bisa pakai apk ini?
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %%
# menghapus tanda baca dan angka

def remove_punctuation_and_number(text):
    text = text.translate(str.maketrans("","",string.punctuation + string.digits))
    text = text.translate(str.maketrans('','','"'))
    return text

df['review'] = df['review'].apply(remove_punctuation_and_number)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                              review  \
# 0                                                                                                                                                                                               aplikasi menyusahkan dimana fungsi software itu untuk mempermudah bukan sebaliknya ini aku jauh dari rumah ke kantor dukcapil buat scan barcode brp kali bolak balik tiap kesini error koneksi mulu padahal jaringan normal bagus 👎
# 1                                                                                                                                                                                            sy sangat kecewa aplikasi yang buruk selesai di daftarkan malah tidak bisa di bukatiap kali di buka kesalahan koneksi tolong lah yang benar saja kalau koneksi belum bisa diandalkan jgn dulu disarankan dan di wajibkan ke masyarakat
# 2                                                                                                                                                                                                                   harus dibuka pake wifi kalo pake paket data pribadi gak bisa alias memuat terus tolong dong admin diperbaiki ya aplikasinya masa harus nyari wifi dulu baru bisa dibuka gak efektif gak efisien dan gak praktis
# 3                                                                                                                                                                         aplikasi nya sangat sangat tdk membantu saat ingin membukanya malah tidak bisa untuk apa dukcapil mewajibkan menginstal aplikasi ini kalo hanya sekedar jadi pajangan di hape tolonglah di perbaiki lagi aplikasinya saat ingin melihat data log in mudah
# 4                                                                                                                                                                                 sudah login berkalikali tetap saja yg muncul jaringan tidak stabil padahal jaringan yg kita gunakan stabilapk ap in saat di butuhkan enggak mau kebuka harus menggunakan jaringan wifi tolong untuk di sesuaikan lagimana kita jauh dari dukcapil
# ...                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 19709  saya pengajuan pembuatan akte sudah  minggu ga ada penjelasan sampai sekarangentah di kerjain entah gimanatolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya giniaplikasi sering kali erorr dan pengajuan diem aja ga ada perubahan proses nya\r\nsaya mau tanya\r\nkenapa sih urusan kependudukan ini selalu ribetdatang langsung ribetini udah pake aplikasi bukan nya mudah malah ribet juga
# 19710                                                                                                                                                                                                                                                                            aplikasinya ga bisa dipake force closed terus pada saat ambil foto pas buka lagi dari awal lagi input nik dll\r\nga bisa dipakai tolong diperbaiki
# 19711                                                                                                                                                                                                                                                         mau register harus ke dukcapil untuk dapat qr buat apa si… \r\nharusnya bisa lebih di simplekan biar semua itu online klo harus datang ke dukcapil ma sama aja boong…
# 19712                                                                                                                                                                                                                                                                                                                                                                                          korup bermodalkan aplikasi cuihhhhhh
# 19713                                                                                                                                                                                                                                                                                                                                                                               nik gua  digit gimana\r\ngak bisa pakai apk ini
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %%
# menghapus emoji

def remove_emoji(text):
    correct = re.compile(pattern="["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return correct.sub(r'',text)

df['review'] = df['review'].apply(remove_emoji)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                              review  \
# 0                                                                                                                                                                                                aplikasi menyusahkan dimana fungsi software itu untuk mempermudah bukan sebaliknya ini aku jauh dari rumah ke kantor dukcapil buat scan barcode brp kali bolak balik tiap kesini error koneksi mulu padahal jaringan normal bagus
# 1                                                                                                                                                                                            sy sangat kecewa aplikasi yang buruk selesai di daftarkan malah tidak bisa di bukatiap kali di buka kesalahan koneksi tolong lah yang benar saja kalau koneksi belum bisa diandalkan jgn dulu disarankan dan di wajibkan ke masyarakat
# 2                                                                                                                                                                                                                   harus dibuka pake wifi kalo pake paket data pribadi gak bisa alias memuat terus tolong dong admin diperbaiki ya aplikasinya masa harus nyari wifi dulu baru bisa dibuka gak efektif gak efisien dan gak praktis
# 3                                                                                                                                                                         aplikasi nya sangat sangat tdk membantu saat ingin membukanya malah tidak bisa untuk apa dukcapil mewajibkan menginstal aplikasi ini kalo hanya sekedar jadi pajangan di hape tolonglah di perbaiki lagi aplikasinya saat ingin melihat data log in mudah
# 4                                                                                                                                                                                 sudah login berkalikali tetap saja yg muncul jaringan tidak stabil padahal jaringan yg kita gunakan stabilapk ap in saat di butuhkan enggak mau kebuka harus menggunakan jaringan wifi tolong untuk di sesuaikan lagimana kita jauh dari dukcapil
# ...                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 19709  saya pengajuan pembuatan akte sudah  minggu ga ada penjelasan sampai sekarangentah di kerjain entah gimanatolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya giniaplikasi sering kali erorr dan pengajuan diem aja ga ada perubahan proses nya\r\nsaya mau tanya\r\nkenapa sih urusan kependudukan ini selalu ribetdatang langsung ribetini udah pake aplikasi bukan nya mudah malah ribet juga
# 19710                                                                                                                                                                                                                                                                            aplikasinya ga bisa dipake force closed terus pada saat ambil foto pas buka lagi dari awal lagi input nik dll\r\nga bisa dipakai tolong diperbaiki
# 19711                                                                                                                                                                                                                                                         mau register harus ke dukcapil untuk dapat qr buat apa si… \r\nharusnya bisa lebih di simplekan biar semua itu online klo harus datang ke dukcapil ma sama aja boong…
# 19712                                                                                                                                                                                                                                                                                                                                                                                          korup bermodalkan aplikasi cuihhhhhh
# 19713                                                                                                                                                                                                                                                                                                                                                                               nik gua  digit gimana\r\ngak bisa pakai apk ini
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %%
# menghapus whitespace pada teks

def remove_whitespace(text):
    correct = str(text)
    correct = re.sub(r"//t",r"\t", correct)
    correct = re.sub(r"( )\1+",r"\1", correct)
    correct = re.sub(r"(\n)\1+",r"\1", correct)
    correct = re.sub(r"(\r)\1+",r"\1", correct)
    correct = re.sub(r"(\t)\1+",r"\1", correct)
    correct = re.sub(r"\n"," ",correct)
    return correct.strip()

df['review'] = df['review'].apply(remove_whitespace)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                           review  \
# 0                                                                                                                                                                                              aplikasi menyusahkan dimana fungsi software itu untuk mempermudah bukan sebaliknya ini aku jauh dari rumah ke kantor dukcapil buat scan barcode brp kali bolak balik tiap kesini error koneksi mulu padahal jaringan normal bagus
# 1                                                                                                                                                                                         sy sangat kecewa aplikasi yang buruk selesai di daftarkan malah tidak bisa di bukatiap kali di buka kesalahan koneksi tolong lah yang benar saja kalau koneksi belum bisa diandalkan jgn dulu disarankan dan di wajibkan ke masyarakat
# 2                                                                                                                                                                                                                harus dibuka pake wifi kalo pake paket data pribadi gak bisa alias memuat terus tolong dong admin diperbaiki ya aplikasinya masa harus nyari wifi dulu baru bisa dibuka gak efektif gak efisien dan gak praktis
# 3                                                                                                                                                                      aplikasi nya sangat sangat tdk membantu saat ingin membukanya malah tidak bisa untuk apa dukcapil mewajibkan menginstal aplikasi ini kalo hanya sekedar jadi pajangan di hape tolonglah di perbaiki lagi aplikasinya saat ingin melihat data log in mudah
# 4                                                                                                                                                                              sudah login berkalikali tetap saja yg muncul jaringan tidak stabil padahal jaringan yg kita gunakan stabilapk ap in saat di butuhkan enggak mau kebuka harus menggunakan jaringan wifi tolong untuk di sesuaikan lagimana kita jauh dari dukcapil
# ...                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 19709  saya pengajuan pembuatan akte sudah minggu ga ada penjelasan sampai sekarangentah di kerjain entah gimanatolong kalo sistem mau pakai aplikasi seperti ini buat team khusus biar ga kaya giniaplikasi sering kali erorr dan pengajuan diem aja ga ada perubahan proses nya\r saya mau tanya\r kenapa sih urusan kependudukan ini selalu ribetdatang langsung ribetini udah pake aplikasi bukan nya mudah malah ribet juga
# 19710                                                                                                                                                                                                                                                                          aplikasinya ga bisa dipake force closed terus pada saat ambil foto pas buka lagi dari awal lagi input nik dll\r ga bisa dipakai tolong diperbaiki
# 19711                                                                                                                                                                                                                                                       mau register harus ke dukcapil untuk dapat qr buat apa si… \r harusnya bisa lebih di simplekan biar semua itu online klo harus datang ke dukcapil ma sama aja boong…
# 19712                                                                                                                                                                                                                                                                                                                                                                                       korup bermodalkan aplikasi cuihhhhhh
# 19713                                                                                                                                                                                                                                                                                                                                                                              nik gua digit gimana\r gak bisa pakai apk ini
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# text tokenization

def tokenization(text):
    text = word_tokenize(text)
    return text

df['review'] = df['review'].apply(tokenization)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      review  \
# 0                                                                                                                                                                                                                      [aplikasi, menyusahkan, dimana, fungsi, software, itu, untuk, mempermudah, bukan, sebaliknya, ini, aku, jauh, dari, rumah, ke, kantor, dukcapil, buat, scan, barcode, brp, kali, bolak, balik, tiap, kesini, error, koneksi, mulu, padahal, jaringan, normal, bagus]
# 1                                                                                                                                                                                                              [sy, sangat, kecewa, aplikasi, yang, buruk, selesai, di, daftarkan, malah, tidak, bisa, di, bukatiap, kali, di, buka, kesalahan, koneksi, tolong, lah, yang, benar, saja, kalau, koneksi, belum, bisa, diandalkan, jgn, dulu, disarankan, dan, di, wajibkan, ke, masyarakat]
# 2                                                                                                                                                                                                                                       [harus, dibuka, pake, wifi, kalo, pake, paket, data, pribadi, gak, bisa, alias, memuat, terus, tolong, dong, admin, diperbaiki, ya, aplikasinya, masa, harus, nyari, wifi, dulu, baru, bisa, dibuka, gak, efektif, gak, efisien, dan, gak, praktis]
# 3                                                                                                                                                                                          [aplikasi, nya, sangat, sangat, tdk, membantu, saat, ingin, membukanya, malah, tidak, bisa, untuk, apa, dukcapil, mewajibkan, menginstal, aplikasi, ini, kalo, hanya, sekedar, jadi, pajangan, di, hape, tolonglah, di, perbaiki, lagi, aplikasinya, saat, ingin, melihat, data, log, in, mudah]
# 4                                                                                                                                                                                                   [sudah, login, berkalikali, tetap, saja, yg, muncul, jaringan, tidak, stabil, padahal, jaringan, yg, kita, gunakan, stabilapk, ap, in, saat, di, butuhkan, enggak, mau, kebuka, harus, menggunakan, jaringan, wifi, tolong, untuk, di, sesuaikan, lagimana, kita, jauh, dari, dukcapil]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 19709  [saya, pengajuan, pembuatan, akte, sudah, minggu, ga, ada, penjelasan, sampai, sekarangentah, di, kerjain, entah, gimanatolong, kalo, sistem, mau, pakai, aplikasi, seperti, ini, buat, team, khusus, biar, ga, kaya, giniaplikasi, sering, kali, erorr, dan, pengajuan, diem, aja, ga, ada, perubahan, proses, nya, saya, mau, tanya, kenapa, sih, urusan, kependudukan, ini, selalu, ribetdatang, langsung, ribetini, udah, pake, aplikasi, bukan, nya, mudah, malah, ribet, juga]
# 19710                                                                                                                                                                                                                                                                                                             [aplikasinya, ga, bisa, dipake, force, closed, terus, pada, saat, ambil, foto, pas, buka, lagi, dari, awal, lagi, input, nik, dll, ga, bisa, dipakai, tolong, diperbaiki]
# 19711                                                                                                                                                                                                                                                                                       [mau, register, harus, ke, dukcapil, untuk, dapat, qr, buat, apa, si…, harusnya, bisa, lebih, di, simplekan, biar, semua, itu, online, klo, harus, datang, ke, dukcapil, ma, sama, aja, boong…]
# 19712                                                                                                                                                                                                                                                                                                                                                                                                                                             [korup, bermodalkan, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                                                                                                                                                                                                                                                 [nik, gua, digit, gimana, gak, bisa, pakai, apk, ini]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Menghapus Stop Words

# %%
# menghapus stop words dengan Sastrawi

factory = StopWordRemoverFactory()
stopword_sastrawi = factory.get_stop_words()

def remove_stopwords_with_sastrawi(text):
    text = [word for word in text if word not in stopword_sastrawi]
    return text

df['review'] = df['review'].apply(remove_stopwords_with_sastrawi)
df
# Out:
#                                                                                                                                                                                                                                                                                                         review  \
# 0                                                                                                                                    [aplikasi, menyusahkan, dimana, fungsi, software, mempermudah, rumah, kantor, dukcapil, scan, barcode, brp, bolak, kesini, error, koneksi, mulu, jaringan, normal, bagus]
# 1                                                                                                                                                    [sy, kecewa, aplikasi, buruk, selesai, daftarkan, bukatiap, buka, kesalahan, koneksi, tolong, koneksi, diandalkan, jgn, disarankan, wajibkan, masyarakat]
# 2                                                                                                                            [dibuka, pake, wifi, kalo, pake, paket, data, pribadi, gak, alias, memuat, tolong, admin, diperbaiki, aplikasinya, nyari, wifi, dibuka, gak, efektif, gak, efisien, gak, praktis]
# 3                                                                                                                                     [aplikasi, tdk, membantu, membukanya, dukcapil, mewajibkan, menginstal, aplikasi, kalo, sekedar, pajangan, hape, tolonglah, perbaiki, aplikasinya, data, log, in, mudah]
# 4                                                                                                                                                 [login, berkalikali, yg, muncul, jaringan, stabil, jaringan, yg, stabilapk, ap, in, butuhkan, kebuka, jaringan, wifi, tolong, sesuaikan, lagimana, dukcapil]
# ...                                                                                                                                                                                                                                                                                                        ...
# 19709  [pengajuan, pembuatan, akte, minggu, ga, penjelasan, sekarangentah, kerjain, gimanatolong, kalo, sistem, pakai, aplikasi, team, biar, ga, kaya, giniaplikasi, erorr, pengajuan, diem, aja, ga, perubahan, proses, sih, urusan, kependudukan, ribetdatang, ribetini, udah, pake, aplikasi, mudah, ribet]
# 19710                                                                                                                                                                                       [aplikasinya, ga, dipake, force, closed, ambil, foto, pas, buka, input, nik, dll, ga, dipakai, tolong, diperbaiki]
# 19711                                                                                                                                                                                                                   [register, dukcapil, qr, si…, simplekan, biar, online, klo, dukcapil, ma, aja, boong…]
# 19712                                                                                                                                                                                                                                                                [korup, bermodalkan, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                                                                               [nik, gua, digit, gimana, gak, pakai, apk]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Stemming

# %%
# melakukan stemming dengan Sastrawi

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming(text):
    text = [stemmer.stem(token) for token in text]
    return text

df['review'] = df['review'].apply(stemming)
df
# Out:
#                                                                                                                                                                                                                                                                     review  \
# 0                                                                                                                [aplikasi, susah, mana, fungsi, software, mudah, rumah, kantor, dukcapil, scan, barcode, brp, bolak, kesini, error, koneksi, mulu, jaring, normal, bagus]
# 1                                                                                                                                    [sy, kecewa, aplikasi, buruk, selesai, daftar, bukatiap, buka, salah, koneksi, tolong, koneksi, andal, jgn, saran, wajib, masyarakat]
# 2                                                                                                       [buka, pake, wifi, kalo, pake, paket, data, pribadi, gak, alias, muat, tolong, admin, baik, aplikasi, nyari, wifi, buka, gak, efektif, gak, efisien, gak, praktis]
# 3                                                                                                                               [aplikasi, tdk, bantu, buka, dukcapil, wajib, menginstal, aplikasi, kalo, dar, pajang, hape, tolong, baik, aplikasi, data, log, in, mudah]
# 4                                                                                                                           [login, berkalikali, yg, muncul, jaring, stabil, jaring, yg, stabilapk, ap, in, butuh, buka, jaring, wifi, tolong, sesuai, lagimana, dukcapil]
# ...                                                                                                                                                                                                                                                                    ...
# 19709  [aju, buat, akte, minggu, ga, jelas, sekarangentah, kerjain, gimanatolong, kalo, sistem, pakai, aplikasi, team, biar, ga, kaya, giniaplikasi, erorr, aju, diem, aja, ga, ubah, proses, sih, urus, duduk, ribetdatang, ribetini, udah, pake, aplikasi, mudah, ribet]
# 19710                                                                                                                                                              [aplikasi, ga, dipake, force, closed, ambil, foto, pas, buka, input, nik, dll, ga, pakai, tolong, baik]
# 19711                                                                                                                                                                                 [register, dukcapil, qr, si, simplekan, biar, online, klo, dukcapil, ma, aja, boong]
# 19712                                                                                                                                                                                                                                  [korup, modal, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                                           [nik, gua, digit, gimana, gak, pakai, apk]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Perbaikan Ejaan Kata

# %%
# Perbaikan ejaan kata

normalized_word = pd.read_csv("../../../corpus/kamus-alay/colloquial-indonesian-lexicon.csv")

normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

df['review'] = df['review'].apply(normalized_term)
df
# Out:
# C:\Users\zakymzn\AppData\Local\Temp\ipykernel_13532\3809799712.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\zakymzn\AppData\Local\Temp\ipykernel_13532\3809799712.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]
#                                                                                                                                                                                                                                                                                     review  \
# 0                                                                                                                             [aplikasi, susah, mana, fungsi, software, mudah, rumah, kantor, dukcapil, scan, barcode, berapa, bolak, kesini, error, koneksi, mulu, jaring, normal, bagus]
# 1                                                                                                                                               [saya, kecewa, aplikasi, buruk, selesai, daftar, bukatiap, buka, salah, koneksi, tolong, koneksi, andal, jangan, saran, wajib, masyarakat]
# 2                                                                                                       [buka, pakai, wifi, kalo, pakai, paket, data, pribadi, enggak, alias, muat, tolong, admin, baik, aplikasi, mencari, wifi, buka, enggak, efektif, enggak, efisien, enggak, praktis]
# 3                                                                                                                                            [aplikasi, tidak, bantu, buka, dukcapil, wajib, menginstal, aplikasi, kalo, dar, pajang, hape, tolong, baik, aplikasi, data, log, ini, mudah]
# 4                                                                                                                                     [login, berkalikali, yang, muncul, jaring, stabil, jaring, yang, stabilapk, apa, ini, butuh, buka, jaring, wifi, tolong, sesuai, lagimana, dukcapil]
# ...                                                                                                                                                                                                                                                                                    ...
# 19709  [aju, buat, akte, minggu, enggak, jelas, sekarangentah, kerjain, gimanatolong, kalo, sistem, pakai, aplikasi, team, biar, enggak, kayak, giniaplikasi, erorr, aju, diam, saja, enggak, ubah, proses, sih, urus, duduk, ribetdatang, ribetini, sudah, pakai, aplikasi, mudah, ribet]
# 19710                                                                                                                                                                     [aplikasi, enggak, dipakai, force, closed, ambil, foto, pas, buka, input, nik, dll, enggak, pakai, tolong, baik]
# 19711                                                                                                                                                                                           [register, dukcapil, qr, sih, simplekan, biar, online, kalo, dukcapil, sama, saja, bohong]
# 19712                                                                                                                                                                                                                                                  [korup, modal, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                                                     [nik, gua, digit, bagaimana, enggak, pakai, apk]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Menghapus Stop Words

# %%
# menghapus stop words kembali dengan Sastrawi

df['review'] = df['review'].apply(remove_stopwords_with_sastrawi)
df
# Out:
#                                                                                                                                                                                                                                   review  \
# 0                                                                                         [aplikasi, susah, fungsi, software, mudah, rumah, kantor, dukcapil, scan, barcode, bolak, kesini, error, koneksi, mulu, jaring, normal, bagus]
# 1                                                                                                           [kecewa, aplikasi, buruk, selesai, daftar, bukatiap, buka, salah, koneksi, tolong, koneksi, andal, saran, wajib, masyarakat]
# 2                                                                                           [buka, pakai, wifi, kalo, pakai, paket, data, pribadi, alias, muat, tolong, admin, aplikasi, mencari, wifi, buka, efektif, efisien, praktis]
# 3                                                                                                            [aplikasi, bantu, buka, dukcapil, wajib, menginstal, aplikasi, kalo, dar, pajang, hape, tolong, aplikasi, data, log, mudah]
# 4                                                                                                         [login, berkalikali, muncul, jaring, stabil, jaring, stabilapk, butuh, buka, jaring, wifi, tolong, sesuai, lagimana, dukcapil]
# ...                                                                                                                                                                                                                                  ...
# 19709  [aju, akte, minggu, sekarangentah, kerjain, gimanatolong, kalo, sistem, pakai, aplikasi, team, biar, kayak, giniaplikasi, erorr, aju, diam, ubah, proses, sih, urus, duduk, ribetdatang, ribetini, pakai, aplikasi, mudah, ribet]
# 19710                                                                                                                                         [aplikasi, dipakai, force, closed, ambil, foto, pas, buka, input, nik, dll, pakai, tolong]
# 19711                                                                                                                                                     [register, dukcapil, qr, sih, simplekan, biar, online, kalo, dukcapil, bohong]
# 19712                                                                                                                                                                                                [korup, modal, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                      [nik, gua, digit, pakai, apk]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ### Stemming

# %%
# melakukan stemming ulang dengan Sastrawi

df['review'] = df['review'].apply(stemming)
df
# Out:
#                                                                                                                                                                                                                                   review  \
# 0                                                                                         [aplikasi, susah, fungsi, software, mudah, rumah, kantor, dukcapil, scan, barcode, bolak, kesini, error, koneksi, mulu, jaring, normal, bagus]
# 1                                                                                                           [kecewa, aplikasi, buruk, selesai, daftar, bukatiap, buka, salah, koneksi, tolong, koneksi, andal, saran, wajib, masyarakat]
# 2                                                                                              [buka, pakai, wifi, kalo, pakai, paket, data, pribadi, alias, muat, tolong, admin, aplikasi, cari, wifi, buka, efektif, efisien, praktis]
# 3                                                                                                            [aplikasi, bantu, buka, dukcapil, wajib, menginstal, aplikasi, kalo, dar, pajang, hape, tolong, aplikasi, data, log, mudah]
# 4                                                                                                         [login, berkalikali, muncul, jaring, stabil, jaring, stabilapk, butuh, buka, jaring, wifi, tolong, sesuai, lagimana, dukcapil]
# ...                                                                                                                                                                                                                                  ...
# 19709  [aju, akte, minggu, sekarangentah, kerjain, gimanatolong, kalo, sistem, pakai, aplikasi, team, biar, kayak, giniaplikasi, erorr, aju, diam, ubah, proses, sih, urus, duduk, ribetdatang, ribetini, pakai, aplikasi, mudah, ribet]
# 19710                                                                                                                                           [aplikasi, pakai, force, closed, ambil, foto, pas, buka, input, nik, dll, pakai, tolong]
# 19711                                                                                                                                                     [register, dukcapil, qr, sih, simplekan, biar, online, kalo, dukcapil, bohong]
# 19712                                                                                                                                                                                                [korup, modal, aplikasi, cuihhhhhh]
# 19713                                                                                                                                                                                                      [nik, gua, digit, pakai, apk]
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %% [markdown]
# ## WordCloud

# %%
# Menggabungkan kata-kata menjadi satu kalimat per baris

corpus = []

for i in range(len(df['review'])):
    word = df['review'][i]
    row = ' '.join(word)
    corpus.append(row)

df['review'] = corpus
df
# Out:
#                                                                                                                                                                                                      review  \
# 0                                                                               aplikasi susah fungsi software mudah rumah kantor dukcapil scan barcode bolak kesini error koneksi mulu jaring normal bagus
# 1                                                                                              kecewa aplikasi buruk selesai daftar bukatiap buka salah koneksi tolong koneksi andal saran wajib masyarakat
# 2                                                                                     buka pakai wifi kalo pakai paket data pribadi alias muat tolong admin aplikasi cari wifi buka efektif efisien praktis
# 3                                                                                                aplikasi bantu buka dukcapil wajib menginstal aplikasi kalo dar pajang hape tolong aplikasi data log mudah
# 4                                                                                            login berkalikali muncul jaring stabil jaring stabilapk butuh buka jaring wifi tolong sesuai lagimana dukcapil
# ...                                                                                                                                                                                                     ...
# 19709  aju akte minggu sekarangentah kerjain gimanatolong kalo sistem pakai aplikasi team biar kayak giniaplikasi erorr aju diam ubah proses sih urus duduk ribetdatang ribetini pakai aplikasi mudah ribet
# 19710                                                                                                                            aplikasi pakai force closed ambil foto pas buka input nik dll pakai tolong
# 19711                                                                                                                                   register dukcapil qr sih simplekan biar online kalo dukcapil bohong
# 19712                                                                                                                                                                        korup modal aplikasi cuihhhhhh
# 19713                                                                                                                                                                               nik gua digit pakai apk
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 19709   Negatif
# 19710   Negatif
# 19711   Negatif
# 19712   Negatif
# 19713   Negatif
#
# [19714 rows x 2 columns]

# %%
# menampilkan frekuensi kemunculan kata menggunakan wordcloud

words = " ".join(review for review in df['review'])
print(f'Jumlah kata pada dataset adalah {len(words)} kata')

wordcloud = WordCloud(background_color='white').generate(text=words)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Jumlah kata pada dataset adalah 877832 kata

# %% [markdown]
# ### WordCloud Sentimen Positif

# %%
# memisahkan dataframe untuk sentimen positif

df_positive = df.loc[df['sentiment'] == "Positif"].reset_index()
df_positive = df_positive.drop(columns='index')
df_positive
# Out:
#                                                                                                                                                             review  \
# 0     konsep aplikasi bagus tingkat mudah akses konektivitas hubung server simpan data akses offline keluh jaring kendala akses aplikasi kuota internet tingkat ui
# 1                    tolong min dokumen buka pas klik dokumen muncul loading muncul datadata tolong kasih pencerahantutor biar buka koneksi internetdatawifi bagus
# 2                             aplikasi buka pakai wifi towertidak buka pakai data seluler wifi selulertolong batas pakai data pakai wifi hp seri azus mpro bimbing
# 3             loding baca muat warna kuning warna hijau baca loding muat mah aplikasi loding muat nunggunya saran mending warna hijau tinggal klik masuk pin cepat
# 4                       bagus update menu dokumen data kakak info vaksin cantum menu layan tte akses menu tte akses menu sinkronisasi privy biar masyarakat senang
# ...                                                                                                                                                            ...
# 6651                                                                                                                                                       praktis
# 6652                                                                                                                                                 easy register
# 6653                                                                                                                       sedia tte bsre uji kehandalan aman tksh
# 6654                                                                                                                        pin salah pin min solusi opsi lupa pin
# 6655                                                                                                                                                 lumayan bantu
#
#      sentiment
# 0      Positif
# 1      Positif
# 2      Positif
# 3      Positif
# 4      Positif
# ...        ...
# 6651   Positif
# 6652   Positif
# 6653   Positif
# 6654   Positif
# 6655   Positif
#
# [6656 rows x 2 columns]

# %%
# menampilkan wordcloud untuk sentiment positif

positive = " ".join(review for review in df_positive['review'])
print(f'Jumlah kata pada sentimen positif adalah {len(positive)} kata')

wordcloud = WordCloud(background_color='white').generate(text=positive)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Jumlah kata pada sentimen positif adalah 199742 kata

# %% [markdown]
# ### WordCloud Sentimen Negatif

# %%
# memisahkan dataframe untuk sentimen negatif

df_negative = df.loc[df['sentiment'] == "Negatif"].reset_index()
df_negative = df_negative.drop(columns='index')
df_negative
# Out:
#                                                                                                                                                                                                      review  \
# 0                                                                               aplikasi susah fungsi software mudah rumah kantor dukcapil scan barcode bolak kesini error koneksi mulu jaring normal bagus
# 1                                                                                              kecewa aplikasi buruk selesai daftar bukatiap buka salah koneksi tolong koneksi andal saran wajib masyarakat
# 2                                                                                     buka pakai wifi kalo pakai paket data pribadi alias muat tolong admin aplikasi cari wifi buka efektif efisien praktis
# 3                                                                                                aplikasi bantu buka dukcapil wajib menginstal aplikasi kalo dar pajang hape tolong aplikasi data log mudah
# 4                                                                                            login berkalikali muncul jaring stabil jaring stabilapk butuh buka jaring wifi tolong sesuai lagimana dukcapil
# ...                                                                                                                                                                                                     ...
# 13053  aju akte minggu sekarangentah kerjain gimanatolong kalo sistem pakai aplikasi team biar kayak giniaplikasi erorr aju diam ubah proses sih urus duduk ribetdatang ribetini pakai aplikasi mudah ribet
# 13054                                                                                                                            aplikasi pakai force closed ambil foto pas buka input nik dll pakai tolong
# 13055                                                                                                                                   register dukcapil qr sih simplekan biar online kalo dukcapil bohong
# 13056                                                                                                                                                                        korup modal aplikasi cuihhhhhh
# 13057                                                                                                                                                                               nik gua digit pakai apk
#
#       sentiment
# 0       Negatif
# 1       Negatif
# 2       Negatif
# 3       Negatif
# 4       Negatif
# ...         ...
# 13053   Negatif
# 13054   Negatif
# 13055   Negatif
# 13056   Negatif
# 13057   Negatif
#
# [13058 rows x 2 columns]

# %%
# menampilkan wordcloud untuk sentimen negatif

negative = " ".join(review for review in df_negative['review'])
print(f'Jumlah kata pada sentimen negatif adalah {len(negative)} kata')

wordcloud = WordCloud(background_color='white').generate(text=negative)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Jumlah kata pada sentimen negatif adalah 678089 kata

# %% [markdown]
# ## Feature dan Label

# %%
# membagi atribut menjadi features (X) dan label (y)

X = df['review']
y = df['sentiment']

# %%
# menampilkan grafik jumlah data pada kolom sentiment

y.value_counts().plot(kind='bar')
plt.title('Jumlah Data Antar Kelas Sebelum Diseimbangkan')
plt.text(x=-0.075,y=y.value_counts()["Negatif"],s=y.value_counts()["Negatif"])
plt.text(x=0.925,y=y.value_counts()["Positif"],s=y.value_counts()["Positif"])
plt.show()

# %% [markdown]
# ## Pembobotan Kata Menggunakan TF-IDF

# %%
# melakukan pembobotan kata dengan TF-IDF

tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(X)
X_tfidf
# Out:
# <19714x12974 sparse matrix of type '<class 'numpy.float64'>'
# 	with 119242 stored elements in Compressed Sparse Row format>

# %%
# menampilkan hasil tf-idf pada baris data pertama

first_vector = X_tfidf[0]
df_tfidf_first = pd.DataFrame(first_vector.T.todense(), index=tfidf.get_feature_names_out(), columns=['tfidf'])
df_tfidf_first.sort_values(by=['tfidf'], ascending=False).head(10)
# Out:
#              tfidf
# software  0.402342
# kesini    0.353754
# normal    0.329712
# bolak     0.297653
# rumah     0.262720
# error     0.237925
# fungsi    0.236516
# mulu      0.234982
# jaring    0.200401
# kantor    0.193595

# %% [markdown]
# ## Menyeimbangkan Data Menggunakan SMOTE

# %%
# menyeimbangkan data berdasarkan atribut sentiment atau label (y)

oversampler = SMOTE()
X_tfidf_resampled, y_resampled = oversampler.fit_resample(X_tfidf, y)

# %%
# menampilkan kembali grafik jumlah data pada kolom sentiment

y_resampled.value_counts().plot(kind='bar')
plt.title('Jumlah Data Antar Kelas Sesudah Diseimbangkan')
plt.text(x=-0.075,y=y_resampled.value_counts()["Negatif"],s=y_resampled.value_counts()["Negatif"])
plt.text(x=0.925,y=y_resampled.value_counts()["Positif"],s=y_resampled.value_counts()["Positif"])
plt.show()

# %% [markdown]
# ## Pelatihan Model

# %%
# membagi data menjadi data latih (training data) dan data uji (test data)

X_train, X_test, y_train, y_test = train_test_split(X_tfidf_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# inisiasi model machine learning

model = SVC()

# %%
# melatih model

model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Evaluasi

# %%
# memeriksa overfit/underfit

training_accuracy = accuracy_score(y_train, model.predict(X_train))
test_accuracy = accuracy_score(y_test, model.predict(X_test))
print('Training accuracy :', training_accuracy)
print('Test accuracy :', test_accuracy)
print('Difference :', training_accuracy - test_accuracy)
# Out:
# Training accuracy : 0.9558682749377753
# Test accuracy : 0.906010719754977
# Difference : 0.04985755518279822

# %%
# menampilkan confusion matrix

y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.show()

# %%
# melihat hasil laporan klasifikasi

print(classification_report(y_test, y_pred, zero_division=0, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif     0.8789    0.9434    0.9100      2631
#      Positif     0.9379    0.8681    0.9017      2593
#
#     accuracy                         0.9060      5224
#    macro avg     0.9084    0.9057    0.9058      5224
# weighted avg     0.9082    0.9060    0.9059      5224

# %% [markdown]
# ## Simpan Model Menggunakan Joblib

# %%
filename = '../../../models/analisis_sentimen_ikd_dengan_smote.joblib'
joblib.dump(model, filename)
# Out:
# ['../../../models/analisis_sentimen_ikd_dengan_smote.joblib']
