# %%
import numpy as np
import pandas as pd
from app_store_scraper import AppStore
from datetime import date

# %%
ikd = AppStore(country='id', app_name='identitas-kependudukan-digital', app_id='6448944056')
# Out:
# 2024-10-31 10:29:28,679 [INFO] Base - Initialised: AppStore('id', 'identitas-kependudukan-digital', 6448944056)
# 2024-10-31 10:29:28,680 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/id/app/identitas-kependudukan-digital/id6448944056

# %%
ikd.review()
# Out:
# 2024-10-31 10:29:33,742 [INFO] Base - [id:6448944056] Fetched 180 reviews (180 fetched in total)
# 2024-10-31 10:29:39,589 [INFO] Base - [id:6448944056] Fetched 400 reviews (400 fetched in total)
# 2024-10-31 10:29:45,520 [INFO] Base - [id:6448944056] Fetched 600 reviews (600 fetched in total)

# %%
result = ikd.reviews
result
# Out:
# [{'date': datetime.datetime(2023, 12, 14, 13, 31, 40),
#   'review': 'Maaf admin, sebagai masukan. \n\nMasalah: masih ada tahapan yang mana pemohon masih harus ke kantor Dukcapil utk melakukan verifikasi barcode. \n\nSolusi: sekiranya tahapan verifikasi barcode pada kantor dukcapil di gantikan dengan verifikasi online menggunakan vidio interaktif dengan operator dan/atau mengirimi barcode ke email dan/atau nomer tlfn dan/atau cara lainnya yang sifatnya online\n\nTujuan: agar mempermudah dan efektivitas  seluruh tahapan yang dilakukan oleh pemohon dalam pengajuan Identitas Kependudukan Digital tanpa melewati prinsip kehati-hatian dan rahasia data pribadi \n\nHarapan: semoga seluruh produk dukcapil mengenai data diri atau identitas bisa dalam satu app atau superapps dukcapil agar terujud nya goverment yang efektif dan efisien \n\nTerimakasi 🙏🏻',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'APN41',
#   'title': 'Masukan'},
# ...

# %%
len(result)
# Out:
# 600

# %%
df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                    date                                             review  \
# 0   2023-12-14 13:31:40  Maaf admin, sebagai masukan. \n\nMasalah: masi...
# 1   2023-10-10 06:47:32  Admin, mohon bantuan. saya tidak bisa buka dok...
# 2   2023-08-04 08:51:45  Seriusan apanya yang online kalo tetep disuruh...
# 3   2023-08-23 03:20:45  Katanya digital tapi masih diharuskan datang k...
# 4   2023-08-08 13:50:50  Tolong yg bener lah , masa online tapi disuruh...
# ..                  ...                                                ...
# 595 2024-02-28 23:40:25                             BURUK SEKALI EVERYBODY
# 596 2024-02-05 17:37:03  ONLINE DARIMANA UJUNG" NYA DISURUH DTENG KE DU...
# 597 2023-10-08 12:07:57  WKWKWKWK KATANYA ONLINE TP DISURUH SCAN QR KE ...
# 598 2023-06-07 01:34:18   Sangat membantu pelayanan , bintang 100000000000
# 599 2024-10-29 13:56:42  Buat apa sosoan pake aplikasi sosoan online ka...
#
#      rating  isEdited                   userName  \
# ...

# %%
df.count()
# Out:
# date        600
# review      600
# rating      600
# isEdited    600
# userName    600
# title       600
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv(f'../../data/raw/review_ikd_app_store_{date.today().strftime("%d-%m-%Y")}.csv', index=False)
